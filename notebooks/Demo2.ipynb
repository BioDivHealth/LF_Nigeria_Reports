# %% [markdown]
# # PDF Sourcing

# %%
pip install google-cloud-vision pandas
# Out:
# Collecting google-cloud-vision
#   Downloading google_cloud_vision-3.10.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pandas in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.2.3)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading google_api_core-2.24.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from google-cloud-vision) (2.38.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-vision)
#   Downloading proto_plus-1.26.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from google-cloud-vision) (5.29.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2025.1)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading googleapis_common_protos-1.69.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.32.3)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading grpcio-1.70.0-cp311-cp311-macosx_10_14_universal2.whl.metadata (3.9 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading grpcio_status-1.70.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (4.9)
# Requirement already satisfied: six>=1.5 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arturtrebski/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2025.1.31)
# Downloading google_cloud_vision-3.10.0-py2.py3-none-any.whl (523 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 523.4/523.4 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Downloading google_api_core-2.24.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Downloading proto_plus-1.26.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.4 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.69.0-py2.py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.7/169.7 kB 4.4 MB/s eta 0:00:00
# Downloading grpcio-1.70.0-cp311-cp311-macosx_10_14_universal2.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading grpcio_status-1.70.0-py3-none-any.whl (14 kB)
# Installing collected packages: proto-plus, grpcio, googleapis-common-protos, grpcio-status, google-api-core, google-cloud-vision
# Successfully installed google-api-core-2.24.1 google-cloud-vision-3.10.0 googleapis-common-protos-1.69.0 grpcio-1.70.0 grpcio-status-1.70.0 proto-plus-1.26.0
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install requests beautifulsoup4 pytesseract

# %%
# !pip install google-generativeai python-dotenv Pillow pydantic

# %%
import os
import requests
from bs4 import BeautifulSoup

def download_lassa_pdfs():
    # The base URL that hosts the PDFs
    base_url = "https://ncdc.gov.ng"
    # The specific page that lists all the Lassa fever situation reports
    list_page_url = (
        "https://ncdc.gov.ng/diseases/sitreps/?cat=5&name=An%20update%20of%20Lassa%20fever%20outbreak%20in%20Nigeria"
    )
    
    # Create a local folder to store the PDFs
    os.makedirs("pdfs", exist_ok=True)
    
    # 1. Fetch the HTML
    print(f"Fetching list page: {list_page_url}")
    response = requests.get(list_page_url)
    response.raise_for_status()  # raise an error if the HTTP request failed
    
    # 2. Parse the HTML
    soup = BeautifulSoup(response.text, "html.parser")
    
    # The table is inside <tbody>. Each row has multiple <td>, 
    # and the third <td> has the <a> with the PDF link
    table_body = soup.find("tbody")
    if not table_body:
        print("Could not find <tbody> on the page.")
        return
    
    rows = table_body.find_all("tr")
    if not rows:
        print("No <tr> found inside <tbody>.")
        return

    # For stats
    total_found = 0
    total_downloaded = 0
    
    for row in rows:
        cells = row.find_all("td")
        if len(cells) < 3:
            # We expect 3 <td> in each row: (1) index, (2) description, (3) the PDF link
            continue
        
        # The PDF link is in the third cell; let's get the <a>:
        link_tag = cells[2].find("a", href=True)
        if not link_tag:
            continue
        
        # The PDF URL is relative, e.g. "/themes/common/files/sitreps/..."
        # We need to prepend https://ncdc.gov.ng
        pdf_url = link_tag["href"]
        if pdf_url.startswith("/"):
            pdf_url = base_url + pdf_url
        
        # The "download" attribute often has the suggested filename
        # or we can parse from the final part of the URL
        download_name = link_tag.get("download")  # e.g. "An update of Lassa fever ... .pdf"
        
        if not download_name:
            # Fallback: parse the filename from the URL
            download_name = pdf_url.split("/")[-1]

        # Clean up the download name if needed
        download_name = download_name.replace(" ", "_")

        total_found += 1
        # 3. Download the PDF
        # We'll skip if it already exists. Or you can overwrite by removing the check.
        local_path = os.path.join("pdfs", download_name)
        if os.path.exists(local_path):
            print(f"Already downloaded: {download_name}")
            continue
        
        print(f"Downloading {pdf_url} -> {local_path}")
        try:
            pdf_response = requests.get(pdf_url)
            pdf_response.raise_for_status()
            with open(local_path, "wb") as f:
                f.write(pdf_response.content)
            total_downloaded += 1
        except Exception as e:
            print(f"Failed to download {pdf_url}: {e}")

    print(f"Found {total_found} PDF links total. Downloaded {total_downloaded} new PDFs.")

if __name__ == "__main__":
    download_lassa_pdfs()

# %% [markdown]
# ## Downloading all PDFs from all diseases

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Base URL of the directory listing (adjust this to your actual URL)
base_url = "https://ncdc.gov.ng/themes/common/files/sitreps/"

# Folder to save the downloaded PDFs
download_folder = "ALL_SitReps"
os.makedirs(download_folder, exist_ok=True)

# Fetch the HTML content from the base URL
try:
    response = requests.get(base_url)
    response.raise_for_status()
except requests.RequestException as e:
    print(f"Error fetching {base_url}: {e}")
    exit(1)

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# Find all links ending with '.pdf'
pdf_links = [
    link.get("href")
    for link in soup.find_all("a")
    if link.get("href") and link.get("href").lower().endswith(".pdf")
]

print(f"Found {len(pdf_links)} PDF files.")

# Download each PDF file
for pdf_link in pdf_links:
    # Construct the absolute URL in case the href is a relative link.
    pdf_url = urljoin(base_url, pdf_link)
    file_name = os.path.basename(pdf_link)
    file_path = os.path.join(download_folder, file_name)
    print(f"Downloading: {pdf_url}")
    try:
        pdf_response = requests.get(pdf_url)
        pdf_response.raise_for_status()
        with open(file_path, "wb") as f:
            f.write(pdf_response.content)
        print(f"Saved: {file_path}")
    except requests.RequestException as e:
        print(f"Error downloading {pdf_url}: {e}")
# Out:
# Found 1246 PDF files.
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0a0ff32d3952b825be885e945355f25f.pdf
# Saved: ALL_SitReps/0a0ff32d3952b825be885e945355f25f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0a4c89ff97671ba0f363cd1edbec077b.pdf
# Saved: ALL_SitReps/0a4c89ff97671ba0f363cd1edbec077b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0a5b79cb766a64f93a8f2e2738b29656.pdf
# Saved: ALL_SitReps/0a5b79cb766a64f93a8f2e2738b29656.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0a22db7d2c626de19d5becffc24d0293.pdf
# Saved: ALL_SitReps/0a22db7d2c626de19d5becffc24d0293.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0a61bf47e3498906525df7c52d34c371.pdf
# Saved: ALL_SitReps/0a61bf47e3498906525df7c52d34c371.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0aa015568b0325ccac29573ecf89b8fd.pdf
# Saved: ALL_SitReps/0aa015568b0325ccac29573ecf89b8fd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0b706ed7bf785837c88a9f3f4985b75d.pdf
# Saved: ALL_SitReps/0b706ed7bf785837c88a9f3f4985b75d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0b781c3d799fb202186ef85f9977fca8.pdf
# Saved: ALL_SitReps/0b781c3d799fb202186ef85f9977fca8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0b82746f04c2ebc74cc122315d937e5e.pdf
# Saved: ALL_SitReps/0b82746f04c2ebc74cc122315d937e5e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0c0860d1aea6c026f30745da39f02b3a.pdf
# Saved: ALL_SitReps/0c0860d1aea6c026f30745da39f02b3a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0c7a93380102de75e327513ea6a405e6.pdf
# Saved: ALL_SitReps/0c7a93380102de75e327513ea6a405e6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0c1400110ed1323620198233267ae48a.pdf
# Saved: ALL_SitReps/0c1400110ed1323620198233267ae48a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0c333863612f362c6831d24b7b7bd513.pdf
# Saved: ALL_SitReps/0c333863612f362c6831d24b7b7bd513.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0cf05f71c21d526bc96db84f4f326530.pdf
# Saved: ALL_SitReps/0cf05f71c21d526bc96db84f4f326530.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0d57dc7d66355cf2af6421aaed7fe82e.pdf
# Saved: ALL_SitReps/0d57dc7d66355cf2af6421aaed7fe82e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0daa083aeed110eddba8937c1f90a6d9.pdf
# Saved: ALL_SitReps/0daa083aeed110eddba8937c1f90a6d9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0dc05d03f9b0a819fc517e0fed3f6aed.pdf
# Saved: ALL_SitReps/0dc05d03f9b0a819fc517e0fed3f6aed.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0e17cd1ebaf6e8467f937bcaa76e78d9.pdf
# Saved: ALL_SitReps/0e17cd1ebaf6e8467f937bcaa76e78d9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0e22a1d4745032665bbe4146de679e60.pdf
# Saved: ALL_SitReps/0e22a1d4745032665bbe4146de679e60.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0e62a44ecb02457b1c6edbb6aaf8ab84.pdf
# Saved: ALL_SitReps/0e62a44ecb02457b1c6edbb6aaf8ab84.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0f03935c9dec2ee03be543c0399eff22.pdf
# Saved: ALL_SitReps/0f03935c9dec2ee03be543c0399eff22.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0f5638d2919d0eff59b6ad09752fcdc8.pdf
# Saved: ALL_SitReps/0f5638d2919d0eff59b6ad09752fcdc8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0f2332677defbd072e8b797f23a7d0d3.pdf
# Saved: ALL_SitReps/0f2332677defbd072e8b797f23a7d0d3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0fa0c4e9d50ef88f23cc31200eb29963.pdf
# Saved: ALL_SitReps/0fa0c4e9d50ef88f23cc31200eb29963.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0ff25575702973161d6e601b499e4430.pdf
# Saved: ALL_SitReps/0ff25575702973161d6e601b499e4430.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/00c3ab632955d919aee88ad1c471b70b.pdf
# Saved: ALL_SitReps/00c3ab632955d919aee88ad1c471b70b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/00235292b8a3f55c01f9ea2eb15c8d3a.pdf
# Saved: ALL_SitReps/00235292b8a3f55c01f9ea2eb15c8d3a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/007fcb05d1309292c83fa5c97821b2f0.pdf
# Saved: ALL_SitReps/007fcb05d1309292c83fa5c97821b2f0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/009dce0e9448bfe86551e69fb17bd1af.pdf
# Saved: ALL_SitReps/009dce0e9448bfe86551e69fb17bd1af.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/01c65f02fefea247e0d096de778993c7.pdf
# Saved: ALL_SitReps/01c65f02fefea247e0d096de778993c7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/01da63310afc9d21a509e238a9f635b1.pdf
# Saved: ALL_SitReps/01da63310afc9d21a509e238a9f635b1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0102205c38204ea641b4bd2456a1586a.pdf
# Saved: ALL_SitReps/0102205c38204ea641b4bd2456a1586a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/02ca174a32597a1e20536b86bed723c7.pdf
# Saved: ALL_SitReps/02ca174a32597a1e20536b86bed723c7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0248af7855ac9228574bae81ed0cd56f.pdf
# Saved: ALL_SitReps/0248af7855ac9228574bae81ed0cd56f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0250e31face328109d78eb0200c7de2e.pdf
# Saved: ALL_SitReps/0250e31face328109d78eb0200c7de2e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0272ed7be84c61cc890f3dcd67c4bdcc.pdf
# Saved: ALL_SitReps/0272ed7be84c61cc890f3dcd67c4bdcc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/03bbf027e2d1df200a5bf258922b7028.pdf
# Saved: ALL_SitReps/03bbf027e2d1df200a5bf258922b7028.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/030e262a994430efddcbcabdfe7196c3.pdf
# Saved: ALL_SitReps/030e262a994430efddcbcabdfe7196c3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0312a484c76a7aa1e10d5d0ce2cd603e.pdf
# Saved: ALL_SitReps/0312a484c76a7aa1e10d5d0ce2cd603e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0333be87293a7b415b7b8964ef3a67be.pdf
# Saved: ALL_SitReps/0333be87293a7b415b7b8964ef3a67be.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/034860f0b4a3c4fdf25d3a4571586739.pdf
# Saved: ALL_SitReps/034860f0b4a3c4fdf25d3a4571586739.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/04af985c76fde1c229189fcda3d4e2ab.pdf
# Saved: ALL_SitReps/04af985c76fde1c229189fcda3d4e2ab.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0416264e23b2b999059d0c7830ea44fd.pdf
# Saved: ALL_SitReps/0416264e23b2b999059d0c7830ea44fd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0470a09a1c46b5e3670e8d2f0bd2595e.pdf
# Saved: ALL_SitReps/0470a09a1c46b5e3670e8d2f0bd2595e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/048a85c8217c6025fd19249aa96dd266.pdf
# Saved: ALL_SitReps/048a85c8217c6025fd19249aa96dd266.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/05a174a39b57030fe239d73fe2063bb9.pdf
# Saved: ALL_SitReps/05a174a39b57030fe239d73fe2063bb9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/05bcea41217e6131abb75ad7f950701a.pdf
# Saved: ALL_SitReps/05bcea41217e6131abb75ad7f950701a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/05c622219ef22137537e6deb2620df7f.pdf
# Saved: ALL_SitReps/05c622219ef22137537e6deb2620df7f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/05156a13ec688981cc19e4d11108e8aa.pdf
# Saved: ALL_SitReps/05156a13ec688981cc19e4d11108e8aa.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/052c150582fc5a5bbf7fac892f68caa7.pdf
# Saved: ALL_SitReps/052c150582fc5a5bbf7fac892f68caa7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/053c10363a00d61fe7ec7258e0497527.pdf
# Saved: ALL_SitReps/053c10363a00d61fe7ec7258e0497527.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/06bc205d1690a1f558d5d39d829a98ab.pdf
# Saved: ALL_SitReps/06bc205d1690a1f558d5d39d829a98ab.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0611da4d5f72ae1203a60bed4bb34a1b.pdf
# Saved: ALL_SitReps/0611da4d5f72ae1203a60bed4bb34a1b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/06257994ca1e2cdd0a35d71f29d40dbd.pdf
# Saved: ALL_SitReps/06257994ca1e2cdd0a35d71f29d40dbd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0684c3d7aa49ffb2681039f58c510a94.pdf
# Saved: ALL_SitReps/0684c3d7aa49ffb2681039f58c510a94.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/07aad3838349103b474032b8ec4f57b2.pdf
# Saved: ALL_SitReps/07aad3838349103b474032b8ec4f57b2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/07d96b98aa2b156778029f2e20390846.pdf
# Saved: ALL_SitReps/07d96b98aa2b156778029f2e20390846.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/07eb2ff51391f06e6373fea933447816.pdf
# Saved: ALL_SitReps/07eb2ff51391f06e6373fea933447816.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0712913a0a2d4756c89fb5bc5bda636e.pdf
# Saved: ALL_SitReps/0712913a0a2d4756c89fb5bc5bda636e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/07225bbddf01a15c3a2870e43ecc4a76.pdf
# Saved: ALL_SitReps/07225bbddf01a15c3a2870e43ecc4a76.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/07359474110a6ce6b38b57f75feda415.pdf
# Saved: ALL_SitReps/07359474110a6ce6b38b57f75feda415.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/0768c088af0936973efcde8cf9c55354.pdf
# Saved: ALL_SitReps/0768c088af0936973efcde8cf9c55354.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/078a3feb24a74ee4312d4d7252f354f0.pdf
# Saved: ALL_SitReps/078a3feb24a74ee4312d4d7252f354f0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/079b73319c633bc29c2a3d0697ea850e.pdf
# Saved: ALL_SitReps/079b73319c633bc29c2a3d0697ea850e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/079ef69035ed92a2a87efbf4bcdfdcaf.pdf
# Saved: ALL_SitReps/079ef69035ed92a2a87efbf4bcdfdcaf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/08b46a5b29d97b5f05b18b61c86df831.pdf
# Saved: ALL_SitReps/08b46a5b29d97b5f05b18b61c86df831.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/08d74f151b6f0fcf99218871243103f0.pdf
# Saved: ALL_SitReps/08d74f151b6f0fcf99218871243103f0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/08f849471fca42b4788988094ecedaaa.pdf
# Saved: ALL_SitReps/08f849471fca42b4788988094ecedaaa.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/08089d0b12626f617f93af6e8ac64157.pdf
# Saved: ALL_SitReps/08089d0b12626f617f93af6e8ac64157.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/08524ed0797e4de7e5f6bf9ec3493607.pdf
# Saved: ALL_SitReps/08524ed0797e4de7e5f6bf9ec3493607.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/087328431e56c8f1ed645ac4df5fb3c3.pdf
# Saved: ALL_SitReps/087328431e56c8f1ed645ac4df5fb3c3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/089900a60257ef3bc47e00018214b512.pdf
# Saved: ALL_SitReps/089900a60257ef3bc47e00018214b512.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/09b6fefce77c74101b77e453f4dca7fb.pdf
# Saved: ALL_SitReps/09b6fefce77c74101b77e453f4dca7fb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/09ca9050585f6be503661f33dc40abc8.pdf
# Saved: ALL_SitReps/09ca9050585f6be503661f33dc40abc8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/091585a88400e36da62237135e66e177.pdf
# Saved: ALL_SitReps/091585a88400e36da62237135e66e177.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/092b3a8097520beaa9a72da9bcedcac5.pdf
# Saved: ALL_SitReps/092b3a8097520beaa9a72da9bcedcac5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/092ce4fc4e4def9066d8ba39a3cf21d3.pdf
# Saved: ALL_SitReps/092ce4fc4e4def9066d8ba39a3cf21d3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/097a5eb758a5719886701e975a0e8d77.pdf
# Saved: ALL_SitReps/097a5eb758a5719886701e975a0e8d77.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/09764885987185524aaec7b9e462fd51.pdf
# Saved: ALL_SitReps/09764885987185524aaec7b9e462fd51.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1aabc83ea46f825a772894b4a53ab870.pdf
# Saved: ALL_SitReps/1aabc83ea46f825a772894b4a53ab870.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1abaddc4d2c0d3eb091958e48349baf1.pdf
# Saved: ALL_SitReps/1abaddc4d2c0d3eb091958e48349baf1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1ac97f89c12c6fa3e2600a90d4ce6dc8.pdf
# Saved: ALL_SitReps/1ac97f89c12c6fa3e2600a90d4ce6dc8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1aef1af3998e191551d1dde6275f12cb.pdf
# Saved: ALL_SitReps/1aef1af3998e191551d1dde6275f12cb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1b4dfa95dc23025ba81df946bc595cb5.pdf
# Saved: ALL_SitReps/1b4dfa95dc23025ba81df946bc595cb5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1b8c77f32a36bb613327747bb2e060ec.pdf
# Saved: ALL_SitReps/1b8c77f32a36bb613327747bb2e060ec.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1b40aecdc7a9100797389299b2519a38.pdf
# Saved: ALL_SitReps/1b40aecdc7a9100797389299b2519a38.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1b48d704b4c33472bcbd148c4d954621.pdf
# Saved: ALL_SitReps/1b48d704b4c33472bcbd148c4d954621.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1b56bc4fbe3927e1541562a1c9f01f19.pdf
# Saved: ALL_SitReps/1b56bc4fbe3927e1541562a1c9f01f19.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1b474f105a23baed3cdaafe9dfafb221.pdf
# Saved: ALL_SitReps/1b474f105a23baed3cdaafe9dfafb221.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1bc774068e49f60c3bda00326b5212e8.pdf
# Saved: ALL_SitReps/1bc774068e49f60c3bda00326b5212e8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1bded1685f8dc4961a169a274be138c2.pdf
# Saved: ALL_SitReps/1bded1685f8dc4961a169a274be138c2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1bffa39cdea17880ccfac3684a1428dc.pdf
# Saved: ALL_SitReps/1bffa39cdea17880ccfac3684a1428dc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1c2cfbf2bc4fb6e10ba27a335b7bae2c.pdf
# Saved: ALL_SitReps/1c2cfbf2bc4fb6e10ba27a335b7bae2c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1c155c60ba3db9256b4efd7f219f7f46.pdf
# Saved: ALL_SitReps/1c155c60ba3db9256b4efd7f219f7f46.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1ccdc59bff14476162f64fa1c9156eb1.pdf
# Saved: ALL_SitReps/1ccdc59bff14476162f64fa1c9156eb1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1cde1fbf9ebf6bc0dd97d2eeadb08291.pdf
# Saved: ALL_SitReps/1cde1fbf9ebf6bc0dd97d2eeadb08291.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1cecc211200c2e71ad58d9e2f51c5f46.pdf
# Saved: ALL_SitReps/1cecc211200c2e71ad58d9e2f51c5f46.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1d3271f656ea9bd07f3c9885a0b5a26c.pdf
# Saved: ALL_SitReps/1d3271f656ea9bd07f3c9885a0b5a26c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1d5875a96a8ce2f4007305d7ef77604b.pdf
# Saved: ALL_SitReps/1d5875a96a8ce2f4007305d7ef77604b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1daf59c8c484ea3c8eb59feb7bd342fd.pdf
# Saved: ALL_SitReps/1daf59c8c484ea3c8eb59feb7bd342fd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1db2172d5f71018a145ea42ff12340d0.pdf
# Saved: ALL_SitReps/1db2172d5f71018a145ea42ff12340d0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1dc69238ca48e48a919c44b880cb31b0.pdf
# Saved: ALL_SitReps/1dc69238ca48e48a919c44b880cb31b0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1de3662004705c84f1e1d357321ca6ad.pdf
# Saved: ALL_SitReps/1de3662004705c84f1e1d357321ca6ad.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1e2be19cff7622a12ef53d8de1cd7731.pdf
# Saved: ALL_SitReps/1e2be19cff7622a12ef53d8de1cd7731.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1e94e8b822b73695023c436f82979bbd.pdf
# Saved: ALL_SitReps/1e94e8b822b73695023c436f82979bbd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1eb24fee275466e4675d0c558538c5bb.pdf
# Saved: ALL_SitReps/1eb24fee275466e4675d0c558538c5bb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1f1c39c3c68eacf284bddcd5d8d7f5eb.pdf
# Saved: ALL_SitReps/1f1c39c3c68eacf284bddcd5d8d7f5eb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1f9c21a76b566ad1d7c98203cb733379.pdf
# Saved: ALL_SitReps/1f9c21a76b566ad1d7c98203cb733379.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1f695878bb47e41265992af6289be196.pdf
# Saved: ALL_SitReps/1f695878bb47e41265992af6289be196.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1f6833689c121d72ba41839554164d6a.pdf
# Saved: ALL_SitReps/1f6833689c121d72ba41839554164d6a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1f54669911845d3755460b6639184fae.pdf
# Saved: ALL_SitReps/1f54669911845d3755460b6639184fae.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1fbd14391042f8b21efb79ee9f7af219.pdf
# Saved: ALL_SitReps/1fbd14391042f8b21efb79ee9f7af219.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1fca24d7891bee573eb47e61961ac5e4.pdf
# Saved: ALL_SitReps/1fca24d7891bee573eb47e61961ac5e4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/1fea6bf7eb076c245ec38fec672d29dc.pdf
# Saved: ALL_SitReps/1fea6bf7eb076c245ec38fec672d29dc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2ac46be11b2e1ab5529a575f8df97c19.pdf
# Saved: ALL_SitReps/2ac46be11b2e1ab5529a575f8df97c19.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2b2529272850bf1ed7a54e7fd2c3c894.pdf
# Saved: ALL_SitReps/2b2529272850bf1ed7a54e7fd2c3c894.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2bc3f9de3eee50441053e684b0f54cb2.pdf
# Saved: ALL_SitReps/2bc3f9de3eee50441053e684b0f54cb2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2c9bad5c3e2d051f26c2d97b317018a2.pdf
# Saved: ALL_SitReps/2c9bad5c3e2d051f26c2d97b317018a2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2c93d23eabd9ac41e2d998c311fbc997.pdf
# Saved: ALL_SitReps/2c93d23eabd9ac41e2d998c311fbc997.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2c2015ced0591ff2b74695c7103555b9.pdf
# Saved: ALL_SitReps/2c2015ced0591ff2b74695c7103555b9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2cee45c9000a8ccf362dd2a93495ebb4.pdf
# Saved: ALL_SitReps/2cee45c9000a8ccf362dd2a93495ebb4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2d019348c618bc573fe47c7620e2a99e.pdf
# Saved: ALL_SitReps/2d019348c618bc573fe47c7620e2a99e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2d72c2d87622abaa152d7deda73bdd9e.pdf
# Saved: ALL_SitReps/2d72c2d87622abaa152d7deda73bdd9e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2d79b38a9ecd082b8e867e5e31a40a40.pdf
# Saved: ALL_SitReps/2d79b38a9ecd082b8e867e5e31a40a40.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2de8007a4a8063517fe7216c71530289.pdf
# Saved: ALL_SitReps/2de8007a4a8063517fe7216c71530289.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2e23321022dfec363be954c17b94c392.pdf
# Saved: ALL_SitReps/2e23321022dfec363be954c17b94c392.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2f8cf3ce751c92af774d62ef021c77f6.pdf
# Saved: ALL_SitReps/2f8cf3ce751c92af774d62ef021c77f6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2f13b8f58812d693b28ecb94e8d945f8.pdf
# Saved: ALL_SitReps/2f13b8f58812d693b28ecb94e8d945f8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2f250f90dbd5643a82098aa3933d6b3c.pdf
# Saved: ALL_SitReps/2f250f90dbd5643a82098aa3933d6b3c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2fa7f5799999a81a439b196483cb77c3.pdf
# Saved: ALL_SitReps/2fa7f5799999a81a439b196483cb77c3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2fbfe33cd5218650172de767a02733b6.pdf
# Saved: ALL_SitReps/2fbfe33cd5218650172de767a02733b6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/2fd923c3f16ae99e0ddbfa1ced8a0ae9.pdf
# Saved: ALL_SitReps/2fd923c3f16ae99e0ddbfa1ced8a0ae9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a07f747d869d00b0611c1267cb9db94.pdf
# Saved: ALL_SitReps/3a07f747d869d00b0611c1267cb9db94.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a3ed0829df82e7efb703382a1a3c0b6.pdf
# Saved: ALL_SitReps/3a3ed0829df82e7efb703382a1a3c0b6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a4e0ee2f29b7d50784826ea43ac7781.pdf
# Saved: ALL_SitReps/3a4e0ee2f29b7d50784826ea43ac7781.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a4f6781f02c2bd2fe9fd4e8b85d8424.pdf
# Saved: ALL_SitReps/3a4f6781f02c2bd2fe9fd4e8b85d8424.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a5aa9183ac8689daea21962828ac236.pdf
# Saved: ALL_SitReps/3a5aa9183ac8689daea21962828ac236.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a7eebe9efd3008ee7f0a46b1afa9e4b.pdf
# Saved: ALL_SitReps/3a7eebe9efd3008ee7f0a46b1afa9e4b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3a102b52ba580a92cc4c3747981ae8d5.pdf
# Saved: ALL_SitReps/3a102b52ba580a92cc4c3747981ae8d5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3ae118a3642d080ca343f77bb81b1cdf.pdf
# Saved: ALL_SitReps/3ae118a3642d080ca343f77bb81b1cdf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3aef9fe7df17ea80bee09604aa641994.pdf
# Saved: ALL_SitReps/3aef9fe7df17ea80bee09604aa641994.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3af5aba890f7f053220439fda2e2622c.pdf
# Saved: ALL_SitReps/3af5aba890f7f053220439fda2e2622c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3b9c06620479bae2b11d4726e723337b.pdf
# Saved: ALL_SitReps/3b9c06620479bae2b11d4726e723337b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3b40253e4cc331de62e7a57945bd6178.pdf
# Saved: ALL_SitReps/3b40253e4cc331de62e7a57945bd6178.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3b8507697d099ff26cd1b7c417a0ba7f.pdf
# Saved: ALL_SitReps/3b8507697d099ff26cd1b7c417a0ba7f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3ba9d9e2925988d3060cd952582fbaec.pdf
# Saved: ALL_SitReps/3ba9d9e2925988d3060cd952582fbaec.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3c0ca1dfe6271855e6ce538e2594f223.pdf
# Saved: ALL_SitReps/3c0ca1dfe6271855e6ce538e2594f223.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3c3cb855baee38f4c350d5896b25f556.pdf
# Saved: ALL_SitReps/3c3cb855baee38f4c350d5896b25f556.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3c70af0c8c9d636758c5d15211a39924.pdf
# Saved: ALL_SitReps/3c70af0c8c9d636758c5d15211a39924.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3c84f98080af56fa5bae546862d7c1cf.pdf
# Saved: ALL_SitReps/3c84f98080af56fa5bae546862d7c1cf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3c6296efefa303dd06bdd1a2a7f30ea4.pdf
# Saved: ALL_SitReps/3c6296efefa303dd06bdd1a2a7f30ea4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3cba8376ab5a2ff80e462f3437caeb5a.pdf
# Saved: ALL_SitReps/3cba8376ab5a2ff80e462f3437caeb5a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3d79dc3d906ac3606f23157b03f7ea78.pdf
# Saved: ALL_SitReps/3d79dc3d906ac3606f23157b03f7ea78.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3d6914a134ce0fb57b9fdb16b11d7571.pdf
# Saved: ALL_SitReps/3d6914a134ce0fb57b9fdb16b11d7571.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3dd84cbd0e420eb345bbca9bb6e2e437.pdf
# Saved: ALL_SitReps/3dd84cbd0e420eb345bbca9bb6e2e437.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3df00cee793e6c7aa4a6a69e66d3bafd.pdf
# Saved: ALL_SitReps/3df00cee793e6c7aa4a6a69e66d3bafd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3e5ad47a9fb29d12651a8dc61d6950d1.pdf
# Saved: ALL_SitReps/3e5ad47a9fb29d12651a8dc61d6950d1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3e6ff785d3edf12620bfe360c39c04eb.pdf
# Saved: ALL_SitReps/3e6ff785d3edf12620bfe360c39c04eb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3e27ca91b6b3e1b019831cc9c17279e7.pdf
# Saved: ALL_SitReps/3e27ca91b6b3e1b019831cc9c17279e7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3e154ad7cca91ab22cbfec57818a9fcc.pdf
# Saved: ALL_SitReps/3e154ad7cca91ab22cbfec57818a9fcc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3ea8a770ca197c7131f0545bdb6d74a6.pdf
# Saved: ALL_SitReps/3ea8a770ca197c7131f0545bdb6d74a6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3eb8f2c997c5c7ff632ec4e4c0519fea.pdf
# Saved: ALL_SitReps/3eb8f2c997c5c7ff632ec4e4c0519fea.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3f45aa7d759bfc31a928a5647038720c.pdf
# Saved: ALL_SitReps/3f45aa7d759bfc31a928a5647038720c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3f49a26d88968593722d995df54a9df1.pdf
# Saved: ALL_SitReps/3f49a26d88968593722d995df54a9df1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3f8001e5b584fcb8f04f86b7a60e6c2f.pdf
# Saved: ALL_SitReps/3f8001e5b584fcb8f04f86b7a60e6c2f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3fa0cf5c659c47eb9b35ecb2876a5769.pdf
# Saved: ALL_SitReps/3fa0cf5c659c47eb9b35ecb2876a5769.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/3fd8e806fd0b107861895b35ccd273b1.pdf
# Saved: ALL_SitReps/3fd8e806fd0b107861895b35ccd273b1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4a44ef79379330658f030c0911813dab.pdf
# Saved: ALL_SitReps/4a44ef79379330658f030c0911813dab.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4aaa8fb1b4a63e02b8b86969d999b0fa.pdf
# Saved: ALL_SitReps/4aaa8fb1b4a63e02b8b86969d999b0fa.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4b809dc589927582b42a97ce19ebfc77.pdf
# Saved: ALL_SitReps/4b809dc589927582b42a97ce19ebfc77.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4ba60062156d085788e94aa8bb21586b.pdf
# Saved: ALL_SitReps/4ba60062156d085788e94aa8bb21586b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4bbad3afd7d75f66b2bad8817c9c2d36.pdf
# Saved: ALL_SitReps/4bbad3afd7d75f66b2bad8817c9c2d36.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4c0d4474817480017deae30945719b2d.pdf
# Saved: ALL_SitReps/4c0d4474817480017deae30945719b2d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4c8dd2905795784510bb3497c4ed8147.pdf
# Saved: ALL_SitReps/4c8dd2905795784510bb3497c4ed8147.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4c26decf2620d574ecdb49b1e854d054.pdf
# Saved: ALL_SitReps/4c26decf2620d574ecdb49b1e854d054.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4c58e1b53aeabb502be9d780618a33eb.pdf
# Saved: ALL_SitReps/4c58e1b53aeabb502be9d780618a33eb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4c928646d133ba0cde5a7c5731ca2d68.pdf
# Saved: ALL_SitReps/4c928646d133ba0cde5a7c5731ca2d68.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4cbce83fa0a479a54b075a72ad38d34d.pdf
# Saved: ALL_SitReps/4cbce83fa0a479a54b075a72ad38d34d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4cf724df697275485b8f5a572f4f68d6.pdf
# Saved: ALL_SitReps/4cf724df697275485b8f5a572f4f68d6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4cfefe6a56332e90a4c10c9ec43bbe33.pdf
# Saved: ALL_SitReps/4cfefe6a56332e90a4c10c9ec43bbe33.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4d1aa9cc68856d96ac7c9e3cd36ee393.pdf
# Saved: ALL_SitReps/4d1aa9cc68856d96ac7c9e3cd36ee393.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4d9dc2b4aac8a97ce813fc05f836157b.pdf
# Saved: ALL_SitReps/4d9dc2b4aac8a97ce813fc05f836157b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4d875e897520dac264fa277cb7f7b401.pdf
# Saved: ALL_SitReps/4d875e897520dac264fa277cb7f7b401.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4db169f4bc79cf4248fd139b62cfdcc7.pdf
# Saved: ALL_SitReps/4db169f4bc79cf4248fd139b62cfdcc7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4dc61da14fcfc706685f0745721cd385.pdf
# Saved: ALL_SitReps/4dc61da14fcfc706685f0745721cd385.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4dcdab16ce45173e4e0319e06937bfd6.pdf
# Saved: ALL_SitReps/4dcdab16ce45173e4e0319e06937bfd6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4e947f95f2b5cd7826f0f42f44521439.pdf
# Saved: ALL_SitReps/4e947f95f2b5cd7826f0f42f44521439.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4e35452c7f16da3d92ad591c6505b2b1.pdf
# Saved: ALL_SitReps/4e35452c7f16da3d92ad591c6505b2b1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4e49924d82deac921303f7a853684883.pdf
# Saved: ALL_SitReps/4e49924d82deac921303f7a853684883.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4e7858362325de8945ef3ecf69d2d440.pdf
# Saved: ALL_SitReps/4e7858362325de8945ef3ecf69d2d440.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4eda109fcbd433bd34c12b90420c6e12.pdf
# Saved: ALL_SitReps/4eda109fcbd433bd34c12b90420c6e12.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4f9aa39002d0a3f264ca23191b504c48.pdf
# Saved: ALL_SitReps/4f9aa39002d0a3f264ca23191b504c48.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4f9bc59b967d1f4b19d61358595d3546.pdf
# Saved: ALL_SitReps/4f9bc59b967d1f4b19d61358595d3546.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4f51df6f3851ae215e709fe5e461cc4f.pdf
# Saved: ALL_SitReps/4f51df6f3851ae215e709fe5e461cc4f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4f56866783b8c066468d1c3cb398e294.pdf
# Saved: ALL_SitReps/4f56866783b8c066468d1c3cb398e294.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4fb9445cb9e30a27518dfca3224b0c1f.pdf
# Saved: ALL_SitReps/4fb9445cb9e30a27518dfca3224b0c1f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4fc8ad5247203f3cb51ef94a56343e12.pdf
# Saved: ALL_SitReps/4fc8ad5247203f3cb51ef94a56343e12.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4fe0f77ee9ded158df275f6d753be21a.pdf
# Saved: ALL_SitReps/4fe0f77ee9ded158df275f6d753be21a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/4ff9facaf848ab5e69f5cf19bc174cce.pdf
# Saved: ALL_SitReps/4ff9facaf848ab5e69f5cf19bc174cce.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5a05b9790d25b163434660508ae387d9.pdf
# Saved: ALL_SitReps/5a05b9790d25b163434660508ae387d9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5a1a9820f21136842ba43f186b8d09e7.pdf
# Saved: ALL_SitReps/5a1a9820f21136842ba43f186b8d09e7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5a251313aa6a55b5de8b98cd7352aded.pdf
# Saved: ALL_SitReps/5a251313aa6a55b5de8b98cd7352aded.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5b04a2042a0ed671d7b75c4aab034ac5.pdf
# Saved: ALL_SitReps/5b04a2042a0ed671d7b75c4aab034ac5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5b9a656b02d200df53b5ad60c1ea41e7.pdf
# Saved: ALL_SitReps/5b9a656b02d200df53b5ad60c1ea41e7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5b76fe852118c3c4120e200abb7101f5.pdf
# Saved: ALL_SitReps/5b76fe852118c3c4120e200abb7101f5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5b306da6313123f8265283fdfc916d8c.pdf
# Saved: ALL_SitReps/5b306da6313123f8265283fdfc916d8c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5bac5affb8c29a495fa1e8dd39e16862.pdf
# Saved: ALL_SitReps/5bac5affb8c29a495fa1e8dd39e16862.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5bb9bd8253ba7a0e5bfeba65745aa4d0.pdf
# Saved: ALL_SitReps/5bb9bd8253ba7a0e5bfeba65745aa4d0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5bc106540b16eb0f0c3b7a298fa3bca0.pdf
# Saved: ALL_SitReps/5bc106540b16eb0f0c3b7a298fa3bca0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5bfb71f4ee32f0f5d4352ee0fd5df93f.pdf
# Saved: ALL_SitReps/5bfb71f4ee32f0f5d4352ee0fd5df93f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5ca21f31869ca49cd417dfedc5cddb1e.pdf
# Saved: ALL_SitReps/5ca21f31869ca49cd417dfedc5cddb1e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5d057cf5590626b6ba29f828fc60cc0c.pdf
# Saved: ALL_SitReps/5d057cf5590626b6ba29f828fc60cc0c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5d40f81a06701616c6d36bd9ae220863.pdf
# Saved: ALL_SitReps/5d40f81a06701616c6d36bd9ae220863.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5d83a97c894646068cdcaef38cd4da09.pdf
# Saved: ALL_SitReps/5d83a97c894646068cdcaef38cd4da09.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5e50fec4c2832642d66c6420b4d1d73e.pdf
# Saved: ALL_SitReps/5e50fec4c2832642d66c6420b4d1d73e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5e95a6057a297d695dbd70f62eab9ccf.pdf
# Saved: ALL_SitReps/5e95a6057a297d695dbd70f62eab9ccf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5e311c58455f1336147d7dc3eded8f92.pdf
# Saved: ALL_SitReps/5e311c58455f1336147d7dc3eded8f92.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5e344c80d225ed42d3a6b705deb25abf.pdf
# Saved: ALL_SitReps/5e344c80d225ed42d3a6b705deb25abf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5e8470699855513952f3ddd4cd4912bd.pdf
# Saved: ALL_SitReps/5e8470699855513952f3ddd4cd4912bd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5eadae1fe0222655731887f63de69523.pdf
# Saved: ALL_SitReps/5eadae1fe0222655731887f63de69523.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5eef9af2eb3577d6473b13f6daaa58b8.pdf
# Saved: ALL_SitReps/5eef9af2eb3577d6473b13f6daaa58b8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5f0b9d75befc8ec93a94b3940837a4f8.pdf
# Saved: ALL_SitReps/5f0b9d75befc8ec93a94b3940837a4f8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5f63aa8c26fb3ca54e6f3c5c40bb0b20.pdf
# Saved: ALL_SitReps/5f63aa8c26fb3ca54e6f3c5c40bb0b20.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5fc025ac4e08a516535210bcdb2b71e2.pdf
# Saved: ALL_SitReps/5fc025ac4e08a516535210bcdb2b71e2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/5fe7d3be99a0e2a0ad09595705006c14.pdf
# Saved: ALL_SitReps/5fe7d3be99a0e2a0ad09595705006c14.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6a75d31cace93a57dae568d104bdb6f7.pdf
# Saved: ALL_SitReps/6a75d31cace93a57dae568d104bdb6f7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6a852b5455fb7a6dedb19e4e3ddef004.pdf
# Saved: ALL_SitReps/6a852b5455fb7a6dedb19e4e3ddef004.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6ad31ab168524e575a7698554bb15313.pdf
# Saved: ALL_SitReps/6ad31ab168524e575a7698554bb15313.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6b21c963f5ba0121ddc29db0ba65582c.pdf
# Saved: ALL_SitReps/6b21c963f5ba0121ddc29db0ba65582c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6b6953c67d38f45ee1c493a397666eb6.pdf
# Saved: ALL_SitReps/6b6953c67d38f45ee1c493a397666eb6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6b11057472740d6a1621760361bd80a3.pdf
# Saved: ALL_SitReps/6b11057472740d6a1621760361bd80a3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6bd3b9afa442c7ccd4f46478d965354b.pdf
# Saved: ALL_SitReps/6bd3b9afa442c7ccd4f46478d965354b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6be1469dfff46c20950e7eadbb4220f6.pdf
# Saved: ALL_SitReps/6be1469dfff46c20950e7eadbb4220f6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6bf5926f7a053012a5ccf9ce2221107f.pdf
# Saved: ALL_SitReps/6bf5926f7a053012a5ccf9ce2221107f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6bffb035b705a1c4a05ca5070fc36c1a.pdf
# Saved: ALL_SitReps/6bffb035b705a1c4a05ca5070fc36c1a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6c3b11e786fe10ede1b42106ff55ea6d.pdf
# Saved: ALL_SitReps/6c3b11e786fe10ede1b42106ff55ea6d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6c3cf1e472c509190602a5d431c0af1e.pdf
# Saved: ALL_SitReps/6c3cf1e472c509190602a5d431c0af1e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6c4c9312fe78b9acceb99139dd9a3101.pdf
# Saved: ALL_SitReps/6c4c9312fe78b9acceb99139dd9a3101.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6c6bf52c783508fff4c864a4192e4687.pdf
# Saved: ALL_SitReps/6c6bf52c783508fff4c864a4192e4687.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6c3256c88b0f63cb068e401d0010845d.pdf
# Saved: ALL_SitReps/6c3256c88b0f63cb068e401d0010845d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6c65168db995ef6efed944790eb30162.pdf
# Saved: ALL_SitReps/6c65168db995ef6efed944790eb30162.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6ceb272218282b1f512274b6be61b23f.pdf
# Saved: ALL_SitReps/6ceb272218282b1f512274b6be61b23f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6e63fc0f0876c0306c8eba17fd11ca7f.pdf
# Saved: ALL_SitReps/6e63fc0f0876c0306c8eba17fd11ca7f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6e94340ea56cffc0bcb29c15518abf02.pdf
# Saved: ALL_SitReps/6e94340ea56cffc0bcb29c15518abf02.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6e628325639b29d7d84ac9597d64b0d6.pdf
# Saved: ALL_SitReps/6e628325639b29d7d84ac9597d64b0d6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6f0cbc3e17f9913d11c33c4ba18677c0.pdf
# Saved: ALL_SitReps/6f0cbc3e17f9913d11c33c4ba18677c0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6f49603d930f6ce1c3bea37c16610538.pdf
# Saved: ALL_SitReps/6f49603d930f6ce1c3bea37c16610538.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6f284222e59d82cc64966cac5e676fac.pdf
# Saved: ALL_SitReps/6f284222e59d82cc64966cac5e676fac.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6fc4028c21e08d759ff801c807aadb4c.pdf
# Saved: ALL_SitReps/6fc4028c21e08d759ff801c807aadb4c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6fd52ae6dec292847db5edfd96806cf9.pdf
# Saved: ALL_SitReps/6fd52ae6dec292847db5edfd96806cf9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6ffc8c649cd99faf470d3ea3b0a1ca33.pdf
# Saved: ALL_SitReps/6ffc8c649cd99faf470d3ea3b0a1ca33.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/6fff397781387dd2966611edaf776cc4.pdf
# Saved: ALL_SitReps/6fff397781387dd2966611edaf776cc4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7a08ab0eb126f2bd63b04a8a4b719af7.pdf
# Saved: ALL_SitReps/7a08ab0eb126f2bd63b04a8a4b719af7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7a2ef7abd88a2d8825c550ccd574dd4c.pdf
# Saved: ALL_SitReps/7a2ef7abd88a2d8825c550ccd574dd4c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7a48a24e640bcc37e2951ce42cc75e0d.pdf
# Saved: ALL_SitReps/7a48a24e640bcc37e2951ce42cc75e0d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7a48a24e640bcc37e2951ce42cc75e0d.pdf.pdf
# Saved: ALL_SitReps/7a48a24e640bcc37e2951ce42cc75e0d.pdf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7a51cc05fdc15533b15b335b367101f8.pdf
# Saved: ALL_SitReps/7a51cc05fdc15533b15b335b367101f8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7afa8d786ff9ef15246de64fbdc59cec.pdf
# Saved: ALL_SitReps/7afa8d786ff9ef15246de64fbdc59cec.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7b6f47a28a1dcac8f5aa6efe0637f3e4.pdf
# Saved: ALL_SitReps/7b6f47a28a1dcac8f5aa6efe0637f3e4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7b9f4f576635f30bb9e8ce761b224e5c.pdf
# Saved: ALL_SitReps/7b9f4f576635f30bb9e8ce761b224e5c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7b122e4047446980c5e4755437e5bee2.pdf
# Saved: ALL_SitReps/7b122e4047446980c5e4755437e5bee2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7b781485b6f62442c6386d5969afc4b7.pdf
# Saved: ALL_SitReps/7b781485b6f62442c6386d5969afc4b7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7ba9ce49faf09f5212c1dbb48b31184b.pdf
# Saved: ALL_SitReps/7ba9ce49faf09f5212c1dbb48b31184b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7bbbaf87083ecd99da866410b62ef0ac.pdf
# Saved: ALL_SitReps/7bbbaf87083ecd99da866410b62ef0ac.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7bd8491d85d236e0835723f7a4a92158.pdf
# Saved: ALL_SitReps/7bd8491d85d236e0835723f7a4a92158.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7bf47ec98cdac72cc7082e448664dde1.pdf
# Saved: ALL_SitReps/7bf47ec98cdac72cc7082e448664dde1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7bff918b81a8e610200b879d929995d.pdf
# Saved: ALL_SitReps/7bff918b81a8e610200b879d929995d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7c36bfd6b0e250b9366c6425e10dea8d.pdf
# Saved: ALL_SitReps/7c36bfd6b0e250b9366c6425e10dea8d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7c82590af07348f7122ff7f5d4d29505.pdf
# Saved: ALL_SitReps/7c82590af07348f7122ff7f5d4d29505.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7cb4f617dd041a5806fdad3a028e17f2.pdf
# Saved: ALL_SitReps/7cb4f617dd041a5806fdad3a028e17f2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7d16b8fd0d2027a1d7833493318dcfe5.pdf
# Saved: ALL_SitReps/7d16b8fd0d2027a1d7833493318dcfe5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7dccb3c58694ee100f2dd3e0ef462d97.pdf
# Saved: ALL_SitReps/7dccb3c58694ee100f2dd3e0ef462d97.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7e1e0a440e581bc9e81daf73dc9bf31e.pdf
# Saved: ALL_SitReps/7e1e0a440e581bc9e81daf73dc9bf31e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7e5e6ef9392c9d153b616cefe3885568.pdf
# Saved: ALL_SitReps/7e5e6ef9392c9d153b616cefe3885568.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7e9d75f803a0251a3b0e1f671c235aa3.pdf
# Saved: ALL_SitReps/7e9d75f803a0251a3b0e1f671c235aa3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7e52697a59d1228b232a6bf47fd84834.pdf
# Saved: ALL_SitReps/7e52697a59d1228b232a6bf47fd84834.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7e85289cf55818da6810ebee1f339f8f.pdf
# Saved: ALL_SitReps/7e85289cf55818da6810ebee1f339f8f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7ed238e6c1924d7e7fa7b26a25e4d99d.pdf
# Saved: ALL_SitReps/7ed238e6c1924d7e7fa7b26a25e4d99d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7eea856fb051a22e6a05bb223d05da24.pdf
# Saved: ALL_SitReps/7eea856fb051a22e6a05bb223d05da24.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7ef0fa9956d6a2e732a38019d14e79bf.pdf
# Saved: ALL_SitReps/7ef0fa9956d6a2e732a38019d14e79bf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7ef98dd290a65f04f1b1a3c5914c9b0c.pdf
# Saved: ALL_SitReps/7ef98dd290a65f04f1b1a3c5914c9b0c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/7f138ff3f44eb62cab6f0fe49efca748.pdf
# Saved: ALL_SitReps/7f138ff3f44eb62cab6f0fe49efca748.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8a0ec23ad67a7a2fed558574e3a9ce7e.pdf
# Saved: ALL_SitReps/8a0ec23ad67a7a2fed558574e3a9ce7e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8a6a26190381508bcd99dfced09c8b93.pdf
# Saved: ALL_SitReps/8a6a26190381508bcd99dfced09c8b93.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8a9f2ce7de14b5b879eda514372113f4.pdf
# Saved: ALL_SitReps/8a9f2ce7de14b5b879eda514372113f4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8a51d11963af846fb1b1a00ff1948a5a.pdf
# Saved: ALL_SitReps/8a51d11963af846fb1b1a00ff1948a5a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8a72a13340d906f9fce9c7814f963ace.pdf
# Saved: ALL_SitReps/8a72a13340d906f9fce9c7814f963ace.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8a91e60bc2c427332002d07031695eb4.pdf
# Saved: ALL_SitReps/8a91e60bc2c427332002d07031695eb4.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8ab0ce1fdbb78d4a2ee6b160153b0d4b.pdf
# Saved: ALL_SitReps/8ab0ce1fdbb78d4a2ee6b160153b0d4b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8af8c802c7bba7f8734770156a656142.pdf
# Saved: ALL_SitReps/8af8c802c7bba7f8734770156a656142.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8b8bf6f65fd442f2d089922019955cbb.pdf
# Saved: ALL_SitReps/8b8bf6f65fd442f2d089922019955cbb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8b230df0b2f798f9890fc056e686ebff.pdf
# Saved: ALL_SitReps/8b230df0b2f798f9890fc056e686ebff.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8bb5f54dae8d24b843af46028215a0a9.pdf
# Saved: ALL_SitReps/8bb5f54dae8d24b843af46028215a0a9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8bcd2913056c037cbc58d2a0e676f54c.pdf
# Saved: ALL_SitReps/8bcd2913056c037cbc58d2a0e676f54c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8bfad087c362850ced18a95efdaaebbb.pdf
# Saved: ALL_SitReps/8bfad087c362850ced18a95efdaaebbb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8c02d1bf6e3e02aa2adfe144dda40db2.pdf
# Saved: ALL_SitReps/8c02d1bf6e3e02aa2adfe144dda40db2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8c04f2a073c67e11c08a4e2d37a3124b.pdf
# Saved: ALL_SitReps/8c04f2a073c67e11c08a4e2d37a3124b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8c473b3bc2387e06d708228c97f0eb7e.pdf
# Saved: ALL_SitReps/8c473b3bc2387e06d708228c97f0eb7e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8cbeb4a2b91c10ab181cbe31dd8be090.pdf
# Saved: ALL_SitReps/8cbeb4a2b91c10ab181cbe31dd8be090.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8cd1f28009c5208ca52a3338ecf0393d.pdf
# Saved: ALL_SitReps/8cd1f28009c5208ca52a3338ecf0393d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8cd8af6509c7294ac334320b9f5f4d0b.pdf
# Saved: ALL_SitReps/8cd8af6509c7294ac334320b9f5f4d0b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8d04fd2de7312e0d390d10e70223791d.pdf
# Saved: ALL_SitReps/8d04fd2de7312e0d390d10e70223791d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8d609130c4f8dbe6754d32767795c5d7.pdf
# Saved: ALL_SitReps/8d609130c4f8dbe6754d32767795c5d7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8da1323a06d9ebf954246c1b27588ae9.pdf
# Saved: ALL_SitReps/8da1323a06d9ebf954246c1b27588ae9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8dbb75404a86ec5baa979606fcd5c585.pdf
# Saved: ALL_SitReps/8dbb75404a86ec5baa979606fcd5c585.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8de8aa6497873b55a1011465a2b92902.pdf
# Saved: ALL_SitReps/8de8aa6497873b55a1011465a2b92902.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8df7d8ffd471f81e68ea6bd86227b01d.pdf
# Saved: ALL_SitReps/8df7d8ffd471f81e68ea6bd86227b01d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8e3a514ed649c5ca5663c70a5e0254de.pdf
# Saved: ALL_SitReps/8e3a514ed649c5ca5663c70a5e0254de.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8e22fc93c483a168480cfe09f13e2aac.pdf
# Saved: ALL_SitReps/8e22fc93c483a168480cfe09f13e2aac.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8ec85b4cc38b1060199aa795b034ea64.pdf
# Saved: ALL_SitReps/8ec85b4cc38b1060199aa795b034ea64.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/8f6b85b3716e33200510a399348749db.pdf
# Saved: ALL_SitReps/8f6b85b3716e33200510a399348749db.pdf
# ...
# Saved: ALL_SitReps/e9579bc8f3aaeb6c4df906fa0945426a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e15260e385285b02e2f350e8e24514df.pdf
# Saved: ALL_SitReps/e15260e385285b02e2f350e8e24514df.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e32606b3b6d44c2466df620b19d78861.pdf
# Saved: ALL_SitReps/e32606b3b6d44c2466df620b19d78861.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e56712a8067c90c6a7c93b4e233829f5.pdf
# Saved: ALL_SitReps/e56712a8067c90c6a7c93b4e233829f5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e77170f8c90cdfc517455d8202418a52.pdf
# Saved: ALL_SitReps/e77170f8c90cdfc517455d8202418a52.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e564228244eae79b541b01b452121d7a.pdf
# Saved: ALL_SitReps/e564228244eae79b541b01b452121d7a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e4500706560ea8b6a77b2435b5ba3cb8.pdf
# Saved: ALL_SitReps/e4500706560ea8b6a77b2435b5ba3cb8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/e945182787522b1ba2bb4ef39d920202.pdf
# Saved: ALL_SitReps/e945182787522b1ba2bb4ef39d920202.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ea1bb56e795d90f28c78d38cfc3b2284.pdf
# Saved: ALL_SitReps/ea1bb56e795d90f28c78d38cfc3b2284.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ea41af69d6b08fdf990c9ff9a95a5192.pdf
# Saved: ALL_SitReps/ea41af69d6b08fdf990c9ff9a95a5192.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ea6086b0f1325768069c992523ca0453.pdf
# Saved: ALL_SitReps/ea6086b0f1325768069c992523ca0453.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ea10486a906cda5a784574e478b97796.pdf
# Saved: ALL_SitReps/ea10486a906cda5a784574e478b97796.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/eb03b0831f637347db1e3c0718bb16e9.pdf
# Saved: ALL_SitReps/eb03b0831f637347db1e3c0718bb16e9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/eb3be271ad737d5ef29dd8a52225448d.pdf
# Saved: ALL_SitReps/eb3be271ad737d5ef29dd8a52225448d.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/eb4d3170d7750c2829c42c79af214a5e.pdf
# Saved: ALL_SitReps/eb4d3170d7750c2829c42c79af214a5e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/eb959088c813beb00dd33053ca3a771b.pdf
# Saved: ALL_SitReps/eb959088c813beb00dd33053ca3a771b.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ebc66f0db1f2ac955fa991a6fcdf61ca.pdf
# Saved: ALL_SitReps/ebc66f0db1f2ac955fa991a6fcdf61ca.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ec8df9ac6829a5efa14fde05e73efa5e.pdf
# Saved: ALL_SitReps/ec8df9ac6829a5efa14fde05e73efa5e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ec9e1a50455b0cb77c7bce727adc1ed1.pdf
# Saved: ALL_SitReps/ec9e1a50455b0cb77c7bce727adc1ed1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ec68ab42ed2c180ee5ae1666b027e511.pdf
# Saved: ALL_SitReps/ec68ab42ed2c180ee5ae1666b027e511.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ecca8043aba3055891669a605ce5188f.pdf
# Saved: ALL_SitReps/ecca8043aba3055891669a605ce5188f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ecf79ab3895b30553cc0a6a7645abf40.pdf
# Saved: ALL_SitReps/ecf79ab3895b30553cc0a6a7645abf40.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ed4f642dd1b5b1f1adf277e1d48a98f8.pdf
# Saved: ALL_SitReps/ed4f642dd1b5b1f1adf277e1d48a98f8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ed5cb85a91a2efeea39771bf5528d1ed.pdf
# Saved: ALL_SitReps/ed5cb85a91a2efeea39771bf5528d1ed.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ed51b768dd417aad9698161b07ef846c.pdf
# Saved: ALL_SitReps/ed51b768dd417aad9698161b07ef846c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ee0dc4dab90d1c4c9a71ac5ab27f051a.pdf
# Saved: ALL_SitReps/ee0dc4dab90d1c4c9a71ac5ab27f051a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ee2ada672f1d7912b4a5ff45f48ba0b6.pdf
# Saved: ALL_SitReps/ee2ada672f1d7912b4a5ff45f48ba0b6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ee4adfa52f16cdbc79aa8aadcfed8e65.pdf
# Saved: ALL_SitReps/ee4adfa52f16cdbc79aa8aadcfed8e65.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ee7f9cf53ae0e4f1b696c2f4cf3eb0f9.pdf
# Saved: ALL_SitReps/ee7f9cf53ae0e4f1b696c2f4cf3eb0f9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ee453dc5cc062d27e2ac303cb2d4cb2a.pdf
# Saved: ALL_SitReps/ee453dc5cc062d27e2ac303cb2d4cb2a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ee2198a2241f6e67d969a659a54a6242.pdf
# Saved: ALL_SitReps/ee2198a2241f6e67d969a659a54a6242.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/eea2983b5f1c51d4452778a11c40a1c7.pdf
# Saved: ALL_SitReps/eea2983b5f1c51d4452778a11c40a1c7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ef99f80b4f951db90a4dc31a6d095c68.pdf
# Saved: ALL_SitReps/ef99f80b4f951db90a4dc31a6d095c68.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/efc178ff025aac3d5ec4d7347032dd7e.pdf
# Saved: ALL_SitReps/efc178ff025aac3d5ec4d7347032dd7e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f0dc2ead07520b5c5ed6d65e00168aae.pdf
# Saved: ALL_SitReps/f0dc2ead07520b5c5ed6d65e00168aae.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f05dc05cd9a8bfcf8115db65b60a98ae.pdf
# Saved: ALL_SitReps/f05dc05cd9a8bfcf8115db65b60a98ae.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f0579d87d8f6da5453aba9d799578c4a.pdf
# Saved: ALL_SitReps/f0579d87d8f6da5453aba9d799578c4a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f07d0fc498a8f1da8d972d58c1591646.pdf
# Saved: ALL_SitReps/f07d0fc498a8f1da8d972d58c1591646.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f082d940c4decb2e33dfada1904c6b5c.pdf
# Saved: ALL_SitReps/f082d940c4decb2e33dfada1904c6b5c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f1a81c91b23a20e43fa5a6c67d85f316.pdf
# Saved: ALL_SitReps/f1a81c91b23a20e43fa5a6c67d85f316.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f1ad34081d8479ab4614fc8dc6e44b54.pdf
# Saved: ALL_SitReps/f1ad34081d8479ab4614fc8dc6e44b54.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f2fc4aa3778e444792131765e0f81c02.pdf
# Saved: ALL_SitReps/f2fc4aa3778e444792131765e0f81c02.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f3fd5b65c7884bce444a443098769ece.pdf
# Saved: ALL_SitReps/f3fd5b65c7884bce444a443098769ece.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f4b869f4b4af846c08f4ac1c8650c3fc.pdf
# Saved: ALL_SitReps/f4b869f4b4af846c08f4ac1c8650c3fc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f4e54bdfa7457b4f3cdac28d93712a3c.pdf
# Saved: ALL_SitReps/f4e54bdfa7457b4f3cdac28d93712a3c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f5f00c41816f216f0118481848a57699.pdf
# Saved: ALL_SitReps/f5f00c41816f216f0118481848a57699.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f7e7e9580448c0601a779585a10098dd.pdf
# Saved: ALL_SitReps/f7e7e9580448c0601a779585a10098dd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f9c5b3d7327f20c15c3916ff5514fb14.pdf
# Saved: ALL_SitReps/f9c5b3d7327f20c15c3916ff5514fb14.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f14ab9784ebbb3b2b552ff8e461d8182.pdf
# Saved: ALL_SitReps/f14ab9784ebbb3b2b552ff8e461d8182.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f19f1ede2ebd582933233e46235224be.pdf
# Saved: ALL_SitReps/f19f1ede2ebd582933233e46235224be.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f26f95f419026d48bd9d3e177d6a4e0c.pdf
# Saved: ALL_SitReps/f26f95f419026d48bd9d3e177d6a4e0c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f32fb06e959c9d79fc20e82711a0bce1.pdf
# Saved: ALL_SitReps/f32fb06e959c9d79fc20e82711a0bce1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f35e1133814e0a1d9d8fd7c0dc4dec3f.pdf
# Saved: ALL_SitReps/f35e1133814e0a1d9d8fd7c0dc4dec3f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f45d05c6e6473997c663ce00dcc7f790.pdf
# Saved: ALL_SitReps/f45d05c6e6473997c663ce00dcc7f790.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f47cdf05593b9a0bb951f08e03c57aab.pdf
# Saved: ALL_SitReps/f47cdf05593b9a0bb951f08e03c57aab.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f54eddc8d8bed1f4ffc76d46744e7768.pdf
# Saved: ALL_SitReps/f54eddc8d8bed1f4ffc76d46744e7768.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f61d3dfa05fac93cd2e2454265bb5314.pdf
# Saved: ALL_SitReps/f61d3dfa05fac93cd2e2454265bb5314.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f77c624fdcc5d95342b540b375272a00.pdf
# Saved: ALL_SitReps/f77c624fdcc5d95342b540b375272a00.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f89ab5742d8cbd00d4e0e9cf670e45f2.pdf
# Saved: ALL_SitReps/f89ab5742d8cbd00d4e0e9cf670e45f2.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f99ab9adf0f26a1ccc796d7610d40b9c.pdf
# Saved: ALL_SitReps/f99ab9adf0f26a1ccc796d7610d40b9c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f310b3f83f7a6679b5acac6e37e03864.pdf
# Saved: ALL_SitReps/f310b3f83f7a6679b5acac6e37e03864.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f722f4d1e81d6ad8f32cb00859c898d5.pdf
# Saved: ALL_SitReps/f722f4d1e81d6ad8f32cb00859c898d5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f781e8e072592b37f51a19723a01cbba.pdf
# Saved: ALL_SitReps/f781e8e072592b37f51a19723a01cbba.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f986fad8eefe455bafe36a09ba9ff91a.pdf
# Saved: ALL_SitReps/f986fad8eefe455bafe36a09ba9ff91a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f2207a3ebbcec6119eb984cd9aa7c071.pdf
# Saved: ALL_SitReps/f2207a3ebbcec6119eb984cd9aa7c071.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f2746a282333f5118aa4ec1cf88b4faf.pdf
# Saved: ALL_SitReps/f2746a282333f5118aa4ec1cf88b4faf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f3236a536f045f4c918dee1e10cd14b9.pdf
# Saved: ALL_SitReps/f3236a536f045f4c918dee1e10cd14b9.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f6459dcfacf635c7a50e6ae9071199bb.pdf
# Saved: ALL_SitReps/f6459dcfacf635c7a50e6ae9071199bb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f6602dae8b376c69fbc2623eac432251.pdf
# Saved: ALL_SitReps/f6602dae8b376c69fbc2623eac432251.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f7298af3058450556e1781d7651d9588.pdf
# Saved: ALL_SitReps/f7298af3058450556e1781d7651d9588.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f8628eda30627ad5d4de99f8ce60f8f3.pdf
# Saved: ALL_SitReps/f8628eda30627ad5d4de99f8ce60f8f3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f9594a55d4f6a4e0de239863a1751576.pdf
# Saved: ALL_SitReps/f9594a55d4f6a4e0de239863a1751576.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f21864d860e8db13a5d75953a0e8dee6.pdf
# Saved: ALL_SitReps/f21864d860e8db13a5d75953a0e8dee6.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f70238f6814fb0a9ce3bce722b95d531.pdf
# Saved: ALL_SitReps/f70238f6814fb0a9ce3bce722b95d531.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f850197e52de3527d8010fd4e6653c2f.pdf
# Saved: ALL_SitReps/f850197e52de3527d8010fd4e6653c2f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f895562ca914f91f6563a0609569fe1a.pdf
# Saved: ALL_SitReps/f895562ca914f91f6563a0609569fe1a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f218526219ca57e4a0c50d27cf2890bc.pdf
# Saved: ALL_SitReps/f218526219ca57e4a0c50d27cf2890bc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f512710099bce532d2c5161f414dacc3.pdf
# Saved: ALL_SitReps/f512710099bce532d2c5161f414dacc3.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/f9520475350c5ff86dfa232420ade3b5.pdf
# Saved: ALL_SitReps/f9520475350c5ff86dfa232420ade3b5.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fa048bb38fc304f58bfeee64e31cd8ee.pdf
# Saved: ALL_SitReps/fa048bb38fc304f58bfeee64e31cd8ee.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fa7461057248c075c33e014c4540e91f.pdf
# Saved: ALL_SitReps/fa7461057248c075c33e014c4540e91f.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fad375d17fe87cd2c4cf82b6c222ecbb.pdf
# Saved: ALL_SitReps/fad375d17fe87cd2c4cf82b6c222ecbb.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/faef7bf3bf32d686a2eb4c462c99ac97.pdf
# Saved: ALL_SitReps/faef7bf3bf32d686a2eb4c462c99ac97.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fb6a6235a88a3116579586e8628fb76c.pdf
# Saved: ALL_SitReps/fb6a6235a88a3116579586e8628fb76c.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fb9d5a2650ad367b154fa151d3af2216.pdf
# Saved: ALL_SitReps/fb9d5a2650ad367b154fa151d3af2216.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fb983f115651d920a7b5a998f747bdaf.pdf
# Saved: ALL_SitReps/fb983f115651d920a7b5a998f747bdaf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fbd928f6e519973a95887db87fccb5f1.pdf
# Saved: ALL_SitReps/fbd928f6e519973a95887db87fccb5f1.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fd008bee0968c04b1946494d46b08bcd.pdf
# Saved: ALL_SitReps/fd008bee0968c04b1946494d46b08bcd.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fd065377e598ed4fe7522b4164021923.pdf
# Saved: ALL_SitReps/fd065377e598ed4fe7522b4164021923.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fd5d61aa64b53b58e62812c9e0517d58.pdf
# Saved: ALL_SitReps/fd5d61aa64b53b58e62812c9e0517d58.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fd6697fe158c9484cde4bed458df2165.pdf
# Saved: ALL_SitReps/fd6697fe158c9484cde4bed458df2165.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fdc5c1ac9f5c2f5e41eb4e7e553bb12a.pdf
# Saved: ALL_SitReps/fdc5c1ac9f5c2f5e41eb4e7e553bb12a.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fdd6a45aaf14bcde402b723faa79bbde.pdf
# Saved: ALL_SitReps/fdd6a45aaf14bcde402b723faa79bbde.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fe5b9f946d2c794ba181b2a404009a66.pdf
# Saved: ALL_SitReps/fe5b9f946d2c794ba181b2a404009a66.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fe6bfb6b22289ff41303bcee6a93eefc.pdf
# Saved: ALL_SitReps/fe6bfb6b22289ff41303bcee6a93eefc.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fe61a5d7bba46e835a7f6d09bd5343c8.pdf
# Saved: ALL_SitReps/fe61a5d7bba46e835a7f6d09bd5343c8.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fe199262c4ae51b274d85ee2e35072b7.pdf
# Saved: ALL_SitReps/fe199262c4ae51b274d85ee2e35072b7.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/fe48059427a8316a8f7eed00c4ae9072.pdf
# Saved: ALL_SitReps/fe48059427a8316a8f7eed00c4ae9072.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ff0ab3eed6171a39c6cc1ac27f4c4e0e.pdf
# Saved: ALL_SitReps/ff0ab3eed6171a39c6cc1ac27f4c4e0e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ff1dd756935ebe6eec59c163a1c5f5bf.pdf
# Saved: ALL_SitReps/ff1dd756935ebe6eec59c163a1c5f5bf.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ff4e0c1cb2937a348952fc7e090b8851.pdf
# Saved: ALL_SitReps/ff4e0c1cb2937a348952fc7e090b8851.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ff91a48209cd5444ba6f6a610157521e.pdf
# Saved: ALL_SitReps/ff91a48209cd5444ba6f6a610157521e.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ff94f80a9171582287b63df547e782a0.pdf
# Saved: ALL_SitReps/ff94f80a9171582287b63df547e782a0.pdf
# Downloading: https://ncdc.gov.ng/themes/common/files/sitreps/ff64823449ff3e26bfe83e43b2235af4.pdf
# Saved: ALL_SitReps/ff64823449ff3e26bfe83e43b2235af4.pdf

# %%
import os

pdf_files = os.listdir('PDFs')
print(pdf_files)

# %%
import os
import re
from pathlib import Path

def rename_lassa_files(folder_path):
    """
    Renames 'An_update_of_Lassa_fever_outbreak_in_Nigeria_041124_45.pdf'
    to 'Nigeria_04_Nov_24_W45.pdf', extracting day=04, month=11 => 'Nov', year=24,
    and the week number 45.
    
    Args:
        folder_path (str): Path to the folder that contains the PDF files.
    """
    # For mapping month number to short name
    month_map = {
        "01": "Jan", "02": "Feb", "03": "Mar", "04": "Apr",
        "05": "May", "06": "Jun", "07": "Jul", "08": "Aug",
        "09": "Sep", "10": "Oct", "11": "Nov", "12": "Dec",
    }

    folder = Path(folder_path)
    for file_path in folder.iterdir():
        if not file_path.is_file():
            continue
        if not file_path.suffix.lower() == ".pdf":
            continue
        
        old_name = file_path.name
        # Replace spaces with underscores
        old_name = old_name.replace(" ", "_")
        # Example old_name: "An_update_of_Lassa_fever_outbreak_in_Nigeria_041124_45.pdf"
        
        # 1) Split on underscores
        parts = old_name.split("_")
        # e.g. ["An","update","of","Lassa","fever","outbreak","in","Nigeria","041124","45.pdf"]
        
        if len(parts) < 9:
            # If the file name doesn't match the expected pattern, skip it
            print(f"Skipping file (unrecognized pattern): {old_name}")
            continue
        
        # 2) The date chunk is parts[8] like "041124"
        date_str = parts[8]  # "041124"
        
        # 3) The week chunk is in parts[9], but includes ".pdf" at the end, e.g. "45.pdf"
        week_str_pdf = parts[9]  # "45.pdf"
        # Remove ".pdf" from the end
        if week_str_pdf.endswith(".pdf"):
            week_str = week_str_pdf.replace(".pdf", "")
        else:
            print(f"Skipping file (no .pdf in last part): {old_name}")
            continue
        
        # 4) date_str should be 6 characters: DDMMYY
        if len(date_str) != 6:
            print(f"Skipping file (date string not 6 chars): {old_name}")
            continue
        dd = date_str[0:2]   # "04"
        mm = date_str[2:4]   # "11"
        yy = date_str[4:6]   # "24"
        
        # 5) Convert mm => month name
        month_name = month_map.get(mm, "???" )  # fallback "???"
        
        # 6) Build new name
        # e.g. "Nigeria_04_Nov_24_W45.pdf"
        new_name = f"Nigeria_{dd}_{month_name}_{yy}_W{week_str}.pdf"
        
        new_path = folder / new_name
        # 7) Rename the file
        print(f"Renaming:\n  {old_name}\n-> {new_name}\n")
        file_path.rename(new_path)

# Example usage:
if __name__ == "__main__":
    rename_lassa_files("downloaded")
# Out:
# Renaming:
#   An_update_of_Lassa_fever_outbreak_in_Nigeria_210923_39.pdf
# -> Nigeria_21_Sep_23_W39.pdf
#
# Renaming:
#   An_update_of_Lassa_fever_outbreak_in_Nigeria_020123_1.pdf
# -> Nigeria_02_Jan_23_W1.pdf
#
# Renaming:
#   An_update_of_Lassa_fever_outbreak_in_Nigeria_050123_2.pdf
# -> Nigeria_05_Jan_23_W2.pdf
#
# Renaming:
#   An_update_of_Lassa_fever_outbreak_in_Nigeria_140923_38.pdf
# -> Nigeria_14_Sep_23_W38.pdf

# %% [markdown]
# ## PDFs for 2024

# %%
import os
import re
all_pdfs = [f for f in os.listdir("PDFs") if f.endswith(".pdf")]
pdfs_2024 = [f for f in all_pdfs if "_24_W" in f]
#print("PDFs for 2024:", pdfs_2024)

sorted_pdfs = sorted(pdfs_2024, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

print("Sorted PDFs for 2024:", sorted_pdfs)
print("Total PDFs for 2024:", len(sorted_pdfs))

# %% [markdown]
# ## PDFs for 2023

# %%
import os
import re
all_pdfs = [f for f in os.listdir("PDFs") if f.endswith(".pdf")]
pdfs_2023 = [f for f in all_pdfs if "_23_W" in f]

sorted_pdfs = sorted(pdfs_2023, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

print("Sorted PDFs for 2023:", sorted_pdfs)
print("Number of PDFs for 2023:", len(sorted_pdfs))
# Calculate missing week numbers
all_weeks = set(range(1, 53))  # Weeks 1-52
existing_week_numbers = set(int(re.search(r'_W(\d+)\.pdf$', pdf).group(1)) for pdf in pdfs_2023)
missing_weeks = sorted(all_weeks - existing_week_numbers)

print("\nMissing weeks for 2023:", missing_weeks)
print("Number of missing weeks:", len(missing_weeks))
# Out:
# Sorted PDFs for 2023: ['Nigeria_02_Jan_23_W1.pdf', 'Nigeria_05_Jan_23_W2.pdf', 'Nigeria_12_Jan_23_W3.pdf', 'Nigeria_19_Jan_23_W4.pdf', 'Nigeria_26_Jan_23_W5.pdf', 'Nigeria_02_Feb_23_W6.pdf', 'Nigeria_09_Feb_23_W7.pdf', 'Nigeria_16_Feb_23_W8.pdf', 'Nigeria_23_Feb_23_W9.pdf', 'Nigeria_02_Mar_23_W10.pdf', 'Nigeria_09_Mar_23_W11.pdf', 'Nigeria_16_Mar_23_W12.pdf', 'Nigeria_23_Mar_23_W13.pdf', 'Nigeria_30_Mar_23_W14.pdf', 'Nigeria_06_Apr_23_W15.pdf', 'Nigeria_13_Apr_23_W16.pdf', 'Nigeria_17_Apr_23_W17.pdf', 'Nigeria_24_Apr_23_W18.pdf', 'Nigeria_04_May_23_W19.pdf', 'Nigeria_11_May_23_W20.pdf', 'Nigeria_18_May_23_W21.pdf', 'Nigeria_25_May_23_W22.pdf', 'Nigeria_01_Jun_23_W23.pdf', 'Nigeria_08_Jun_23_W24.pdf', 'Nigeria_15_Jun_23_W25.pdf', 'Nigeria_22_Jun_23_W26.pdf', 'Nigeria_29_Jun_23_W27.pdf', 'Nigeria_06_Jul_23_W28.pdf', 'Nigeria_13_Jul_23_W29.pdf', 'Nigeria_20_Jul_23_W30.pdf', 'Nigeria_27_Jul_23_W31.pdf', 'Nigeria_03_Aug_23_W32.pdf', 'Nigeria_10_Aug_23_W33.pdf', 'Nigeria_17_Aug_23_W34.pdf', 'Nigeria_24_Aug_23_W35.pdf', 'Nigeria_31_Aug_23_W36.pdf', 'Nigeria_07_Sep_23_W37.pdf', 'Nigeria_14_Sep_23_W38.pdf', 'Nigeria_21_Sep_23_W39.pdf', 'Nigeria_28_Sep_23_W40.pdf', 'Nigeria_05_Oct_23_W41.pdf', 'Nigeria_12_Oct_23_W42.pdf', 'Nigeria_19_Oct_23_W43.pdf', 'Nigeria_26_Oct_23_W44.pdf', 'Nigeria_02_Nov_23_W45.pdf', 'Nigeria_09_Nov_23_W46.pdf', 'Nigeria_16_Nov_23_W47.pdf', 'Nigeria_23_Nov_23_W48.pdf', 'Nigeria_30_Nov_23_W49.pdf', 'Nigeria_07_Dec_23_W50.pdf', 'Nigeria_14_Dec_23_W51.pdf', 'Nigeria_21_Dec_23_W52.pdf']
# Number of PDFs for 2023: 52
#
# Missing weeks for 2023: []
# Number of missing weeks: 0

# %% [markdown]
# ## PDFs for 2022

# %%
import os
import re
from pathlib import Path

# Option 1: Use absolute path
BASE_DIR = Path('/Users/arturtrebski/Documents/Lassa_Reports_Scraping')

# Option 2: Use relative path from notebook location
# BASE_DIR = Path.cwd().parent  # if notebook is in a notebooks subdirectory

#FOLDER = BASE_DIR / 'data' / 'raw' / 'year' / '2021'
FOLDER = BASE_DIR / 'data' / 'raw' / 'yearly_pdfs' / 'PDFs_2021'

# Ensure directory exists
FOLDER.mkdir(parents=True, exist_ok=True)

all_pdfs = [f for f in os.listdir(FOLDER) if f.endswith(".pdf")]
pdfs = [f for f in all_pdfs if "_21_W" in f]

sorted_pdfs = sorted(pdfs, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

print("Sorted PDFs for year:", sorted_pdfs)
print("Number of PDFs for year:", len(sorted_pdfs))

# Calculate missing week numbers
all_weeks = set(range(1, 53))  # Weeks 1-52
existing_week_numbers = set(int(re.search(r'_W(\d+)\.pdf$', pdf).group(1)) for pdf in pdfs)
missing_weeks = sorted(all_weeks - existing_week_numbers)

print("\nMissing weeks for 2024:", missing_weeks)
print("Number of missing weeks:", len(missing_weeks))
# Out:
# Sorted PDFs for year: ['Nigeria_01_Jan_21_W1.pdf', 'Nigeria_08_Jan_21_W2.pdf', 'Nigeria_15_Jan_21_W3.pdf', 'Nigeria_22_Jan_21_W4.pdf', 'Nigeria_29_Jan_21_W5.pdf', 'Nigeria_05_Feb_21_W6.pdf', 'Nigeria_12_Feb_21_W7.pdf', 'Nigeria_19_Feb_21_W8.pdf', 'Nigeria_26_Feb_21_W9.pdf', 'Nigeria_05_Mar_21_W10.pdf', 'Nigeria_12_Mar_21_W11.pdf', 'Nigeria_19_Mar_21_W12.pdf', 'Nigeria_26_Mar_21_W13.pdf', 'Nigeria_02_Apr_21_W14.pdf', 'Nigeria_09_Apr_21_W15.pdf', 'Nigeria_16_Apr_21_W16.pdf', 'Nigeria_23_Apr_21_W17.pdf', 'Nigeria_30_Apr_21_W18.pdf', 'Nigeria_07_May_21_W19.pdf', 'Nigeria_14_May_21_W20.pdf', 'Nigeria_28_May_21_W22.pdf', 'Nigeria_18_Jun_21_W25.pdf', 'Nigeria_25_Jun_21_W26.pdf', 'Nigeria_02_Jul_21_W27.pdf', 'Nigeria_09_Jul_21_W28.pdf', 'Nigeria_16_Jul_21_W29.pdf', 'Nigeria_30_Jul_21_W31.pdf', 'Nigeria_13_Aug_21_W33.pdf', 'Nigeria_20_Aug_21_W34.pdf', 'Nigeria_27_Aug_21_W35.pdf', 'Nigeria_03_Sep_21_W36.pdf', 'Nigeria_10_Sep_21_W37.pdf', 'Nigeria_17_Sep_21_W38.pdf', 'Nigeria_24_Sep_21_W39.pdf', 'Nigeria_01_Oct_21_W40.pdf', 'Nigeria_08_Oct_21_W41.pdf', 'Nigeria_15_Oct_21_W42.pdf', 'Nigeria_22_Oct_21_W43.pdf', 'Nigeria_29_Oct_21_W44.pdf', 'Nigeria_06_Nov_21_W45.pdf', 'Nigeria_13_Nov_21_W46.pdf', 'Nigeria_20_Nov_21_W47.pdf', 'Nigeria_27_Nov_21_W48.pdf', 'Nigeria_04_Dec_21_W49.pdf', 'Nigeria_11_Dec_21_W50.pdf', 'Nigeria_18_Dec_21_W51.pdf', 'Nigeria_25_Dec_21_W52.pdf']
# Number of PDFs for year: 47
#
# Missing weeks for 2024: [21, 23, 24, 30, 32]
# Number of missing weeks: 5

# %%
import csv

data = [
    ['Year', 'Week', 'Status', 'Notes'],
    ['2024', 'W16', 'Missing', 'Duplicate of W17'],
    ['2023', 'W1', 'Found', 'Website link was wrong'],
    ['2023', 'W38', 'Found', 'Website link was wrong'],
    ['2022', 'W21', 'Missing', 'Not found'],
    ['2022', 'W22', 'Found', 'Initially missing but found'],
    ['2022', 'W2', 'Corrupted', 'Need removal'],
    ['2022', 'W14', 'Corrupted', 'Need removal'],
    ['2022', 'W19', 'Corrupted', 'Need removal'],
    ['2022', 'W20', 'Corrupted', 'Need removal'],
    ['2022', 'W23', 'Corrupted', 'Need removal'],
    ['2021', 'W24', 'Missing', 'Not found'],
    ['2021', 'W21', 'Corrupted', 'Need removal'],
    ['2021', 'W23', 'Corrupted', 'Need removal'],
    ['2021', 'W30', 'Corrupted', 'Need removal'],
    ['2021', 'W32', 'Corrupted', 'Need removal']
]

file_name = 'file_status.csv'

# Option 1: Use absolute path
BASE_DIR = Path('/Users/arturtrebski/Documents/Lassa_Reports_Scraping')

#FOLDER = BASE_DIR / 'data' / 'raw' / 'year' / '2021'
FOLDER = BASE_DIR / 'data' / 'documentation'

output_file = FOLDER / file_name

with open(output_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print(f"Created {output_file} with {len(data)-1} entries")
# Out:
# Created /Users/arturtrebski/Documents/Lassa_Reports_Scraping/data/documentation/file_status.csv with 15 entries

# %%
import os
import re
all_pdfs = [f for f in os.listdir("PDFs") if f.endswith(".pdf")]
pdfs_2022 = [f for f in all_pdfs if "_22_W" in f]

sorted_pdfs = sorted(pdfs_2022, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

print("Sorted PDFs for 2022:", sorted_pdfs)
print("Number of PDFs for 2022:", len(sorted_pdfs))
# Calculate missing week numbers
all_weeks = set(range(1, 53))  # Weeks 1-52
existing_week_numbers = set(int(re.search(r'_W(\d+)\.pdf$', pdf).group(1)) for pdf in pdfs_2022)
missing_weeks = sorted(all_weeks - existing_week_numbers)

print("\nMissing weeks for 2022:", missing_weeks)
print("Number of missing weeks:", len(missing_weeks))

# Create the target directory if it doesn't exist
os.makedirs("2022/PDFs_2022", exist_ok=True)

# Copy each 2022 PDF to the target directory
for pdf in sorted_pdfs:
    src_path = os.path.join("PDFs", pdf)
    dst_path = os.path.join("2022/PDFs_2022", pdf)
    if os.path.exists(src_path):
        shutil.copy2(src_path, dst_path)
        print(f"Copied {pdf} to 2022/PDFs_2022/")
    else:
        print(f"Source file not found: {src_path}")

# %% [markdown]
# ## PDFs for 2021

# %%
import os
import re
all_pdfs = [f for f in os.listdir("PDFs") if f.endswith(".pdf")]
pdfs_2021 = [f for f in all_pdfs if "_21_W" in f]

sorted_pdfs = sorted(pdfs_2021, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

print("Sorted PDFs for 2021:", sorted_pdfs)
print("Number of PDFs for 2021:", len(sorted_pdfs))
# Calculate missing week numbers
all_weeks = set(range(1, 53))  # Weeks 1-52
existing_week_numbers = set(int(re.search(r'_W(\d+)\.pdf$', pdf).group(1)) for pdf in pdfs_2021)
missing_weeks = sorted(all_weeks - existing_week_numbers)

print("\nMissing weeks for 2021:", missing_weeks)
print("Number of missing weeks:", len(missing_weeks))

# Create the target directory if it doesn't exist
os.makedirs("2021/PDFs_2021", exist_ok=True)

# Copy each 2021 PDF to the target directory
for pdf in sorted_pdfs:
    src_path = os.path.join("PDFs", pdf)
    dst_path = os.path.join("2021/PDFs_2021", pdf)
    if os.path.exists(src_path):
        shutil.copy2(src_path, dst_path)
        print(f"Copied {pdf} to 2021/PDFs_2021/")
    else:
        print(f"Source file not found: {src_path}")
# Out:
# Sorted PDFs for 2021: ['Nigeria_01_Jan_21_W1.pdf', 'Nigeria_08_Jan_21_W2.pdf', 'Nigeria_15_Jan_21_W3.pdf', 'Nigeria_22_Jan_21_W4.pdf', 'Nigeria_29_Jan_21_W5.pdf', 'Nigeria_05_Feb_21_W6.pdf', 'Nigeria_12_Feb_21_W7.pdf', 'Nigeria_19_Feb_21_W8.pdf', 'Nigeria_26_Feb_21_W9.pdf', 'Nigeria_05_Mar_21_W10.pdf', 'Nigeria_12_Mar_21_W11.pdf', 'Nigeria_19_Mar_21_W12.pdf', 'Nigeria_26_Mar_21_W13.pdf', 'Nigeria_02_Apr_21_W14.pdf', 'Nigeria_09_Apr_21_W15.pdf', 'Nigeria_16_Apr_21_W16.pdf', 'Nigeria_23_Apr_21_W17.pdf', 'Nigeria_30_Apr_21_W18.pdf', 'Nigeria_07_May_21_W19.pdf', 'Nigeria_14_May_21_W20.pdf', 'Nigeria_21_May_21_W21.pdf', 'Nigeria_28_May_21_W22.pdf', 'Nigeria_04_Jun_21_W23.pdf', 'Nigeria_18_Jun_21_W25.pdf', 'Nigeria_25_Jun_21_W26.pdf', 'Nigeria_02_Jul_21_W27.pdf', 'Nigeria_09_Jul_21_W28.pdf', 'Nigeria_16_Jul_21_W29.pdf', 'Nigeria_23_Jul_21_W30.pdf', 'Nigeria_30_Jul_21_W31.pdf', 'Nigeria_06_Aug_21_W32.pdf', 'Nigeria_13_Aug_21_W33.pdf', 'Nigeria_20_Aug_21_W34.pdf', 'Nigeria_27_Aug_21_W35.pdf', 'Nigeria_03_Sep_21_W36.pdf', 'Nigeria_10_Sep_21_W37.pdf', 'Nigeria_17_Sep_21_W38.pdf', 'Nigeria_24_Sep_21_W39.pdf', 'Nigeria_01_Oct_21_W40.pdf', 'Nigeria_08_Oct_21_W41.pdf', 'Nigeria_15_Oct_21_W42.pdf', 'Nigeria_22_Oct_21_W43.pdf', 'Nigeria_29_Oct_21_W44.pdf', 'Nigeria_06_Nov_21_W45.pdf', 'Nigeria_13_Nov_21_W46.pdf', 'Nigeria_20_Nov_21_W47.pdf', 'Nigeria_27_Nov_21_W48.pdf', 'Nigeria_04_Dec_21_W49.pdf', 'Nigeria_11_Dec_21_W50.pdf', 'Nigeria_18_Dec_21_W51.pdf', 'Nigeria_25_Dec_21_W52.pdf']
# Number of PDFs for 2021: 51
#
# Missing weeks for 2021: [24]
# Number of missing weeks: 1
# Copied Nigeria_01_Jan_21_W1.pdf to 2021/PDFs_2021/
# Copied Nigeria_08_Jan_21_W2.pdf to 2021/PDFs_2021/
# Copied Nigeria_15_Jan_21_W3.pdf to 2021/PDFs_2021/
# Copied Nigeria_22_Jan_21_W4.pdf to 2021/PDFs_2021/
# Copied Nigeria_29_Jan_21_W5.pdf to 2021/PDFs_2021/
# Copied Nigeria_05_Feb_21_W6.pdf to 2021/PDFs_2021/
# Copied Nigeria_12_Feb_21_W7.pdf to 2021/PDFs_2021/
# Copied Nigeria_19_Feb_21_W8.pdf to 2021/PDFs_2021/
# Copied Nigeria_26_Feb_21_W9.pdf to 2021/PDFs_2021/
# Copied Nigeria_05_Mar_21_W10.pdf to 2021/PDFs_2021/
# Copied Nigeria_12_Mar_21_W11.pdf to 2021/PDFs_2021/
# Copied Nigeria_19_Mar_21_W12.pdf to 2021/PDFs_2021/
# Copied Nigeria_26_Mar_21_W13.pdf to 2021/PDFs_2021/
# Copied Nigeria_02_Apr_21_W14.pdf to 2021/PDFs_2021/
# Copied Nigeria_09_Apr_21_W15.pdf to 2021/PDFs_2021/
# Copied Nigeria_16_Apr_21_W16.pdf to 2021/PDFs_2021/
# Copied Nigeria_23_Apr_21_W17.pdf to 2021/PDFs_2021/
# Copied Nigeria_30_Apr_21_W18.pdf to 2021/PDFs_2021/
# Copied Nigeria_07_May_21_W19.pdf to 2021/PDFs_2021/
# Copied Nigeria_14_May_21_W20.pdf to 2021/PDFs_2021/
# Copied Nigeria_21_May_21_W21.pdf to 2021/PDFs_2021/
# Copied Nigeria_28_May_21_W22.pdf to 2021/PDFs_2021/
# Copied Nigeria_04_Jun_21_W23.pdf to 2021/PDFs_2021/
# Copied Nigeria_18_Jun_21_W25.pdf to 2021/PDFs_2021/
# Copied Nigeria_25_Jun_21_W26.pdf to 2021/PDFs_2021/
# Copied Nigeria_02_Jul_21_W27.pdf to 2021/PDFs_2021/
# Copied Nigeria_09_Jul_21_W28.pdf to 2021/PDFs_2021/
# Copied Nigeria_16_Jul_21_W29.pdf to 2021/PDFs_2021/
# Copied Nigeria_23_Jul_21_W30.pdf to 2021/PDFs_2021/
# Copied Nigeria_30_Jul_21_W31.pdf to 2021/PDFs_2021/
# Copied Nigeria_06_Aug_21_W32.pdf to 2021/PDFs_2021/
# Copied Nigeria_13_Aug_21_W33.pdf to 2021/PDFs_2021/
# Copied Nigeria_20_Aug_21_W34.pdf to 2021/PDFs_2021/
# Copied Nigeria_27_Aug_21_W35.pdf to 2021/PDFs_2021/
# Copied Nigeria_03_Sep_21_W36.pdf to 2021/PDFs_2021/
# Copied Nigeria_10_Sep_21_W37.pdf to 2021/PDFs_2021/
# Copied Nigeria_17_Sep_21_W38.pdf to 2021/PDFs_2021/
# Copied Nigeria_24_Sep_21_W39.pdf to 2021/PDFs_2021/
# Copied Nigeria_01_Oct_21_W40.pdf to 2021/PDFs_2021/
# Copied Nigeria_08_Oct_21_W41.pdf to 2021/PDFs_2021/
# Copied Nigeria_15_Oct_21_W42.pdf to 2021/PDFs_2021/
# Copied Nigeria_22_Oct_21_W43.pdf to 2021/PDFs_2021/
# Copied Nigeria_29_Oct_21_W44.pdf to 2021/PDFs_2021/
# Copied Nigeria_06_Nov_21_W45.pdf to 2021/PDFs_2021/
# Copied Nigeria_13_Nov_21_W46.pdf to 2021/PDFs_2021/
# Copied Nigeria_20_Nov_21_W47.pdf to 2021/PDFs_2021/
# Copied Nigeria_27_Nov_21_W48.pdf to 2021/PDFs_2021/
# Copied Nigeria_04_Dec_21_W49.pdf to 2021/PDFs_2021/
# Copied Nigeria_11_Dec_21_W50.pdf to 2021/PDFs_2021/
# Copied Nigeria_18_Dec_21_W51.pdf to 2021/PDFs_2021/
# Copied Nigeria_25_Dec_21_W52.pdf to 2021/PDFs_2021/

# %% [markdown]
# # Main script

# %% [markdown]
# This code works well now!
# Crops images to the bottom of the table avoding the legend and also places vertical lines at correct positions. 2 of the tables had issues with the green rows being detected but can address that later.

# %% [markdown]
# ### Testing code

# %%
pdf = sorted_pdfs[1]
input_pdf = os.path.join("PDFs_2023", pdf)
output_path = os.path.join("PDFs_Lines_2023", f"Lines_{pdf.replace('.pdf','')}_page3.png")
pdf_path = input_pdf
h1 = 40
s1 = 0
v1 = 210
h2 = 50
s2 = 30
v2 = 255
tr1 = 1400
linelength1 = 79
linegap1 = 50
toler1 = 10
page_number = 3
dpi = 600

doc = fitz.open(pdf_path)
page = doc[page_number]

# 1. Render the PDF page at high DPI
pix = page.get_pixmap(dpi=dpi)
img_pil = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
# Convert PIL Image to OpenCV BGR
img = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

height1, width1 = img.shape[:2]
total_pixels = height1 * width1
print("Total pixels =", total_pixels)
print("Width =", width1)

# 2. Convert to HSV & detect green rows
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
target_hsv = np.array([102, 12.66, 92.94], dtype=np.uint8)
tolerance = toler1
lower_green = np.array([h1,  s1,  v1], dtype=np.uint8)  # loosen Hue to ~35–100
upper_green = np.array([h2, s2, v2], dtype=np.uint8)  # allow low Saturation up to 80

#lower_green = np.array([max(0, target_hsv[0] - tolerance), 50, 50]) #original approach
#upper_green = np.array([min(179, target_hsv[0] + tolerance), 255, 255]) #original approach
green_mask = cv2.inRange(hsv, lower_green, upper_green)
green_mask_pil = Image.fromarray(green_mask)
green_mask_pil.save("debug_green_mask.png")

overlay = img.copy()
# Paint those masked pixels bright green in overlay
overlay[green_mask > 0] = [0, 255, 0]
# Blend overlay with original (alpha blending)
alpha = 0.35
overlayed_img = cv2.addWeighted(overlay, alpha, img, 1 - alpha, 0)
overlayed_pil = Image.fromarray(cv2.cvtColor(overlayed_img, cv2.COLOR_BGR2RGB))
overlayed_pil.save("debug_green_overlay.png")
print("Saved overlay image as debug_green_overlay.png")


h_proj_green = np.sum(green_mask, axis=1)
print(h_proj_green)
# Find indices where h_proj_green > 0
non_zero_indices = np.where(h_proj_green > 0)[0]
# Print just the non-zero values
print("Non-zero h_proj_green values:")
#for i in non_zero_indices:
    #print(f"Index={i}, Value={h_proj_green[i]}")        
green_row_indices = np.where(h_proj_green > 500000)[0]  # Original value is 1000 
print(green_row_indices)
if len(green_row_indices) == 0:
    print("No green rows detected.")
    print(pdf_path)
    #return

if len(green_row_indices) == 0:
    top_boundary = 800
    bottom_boundary = 4500
else:
    top_boundary = green_row_indices[1]
    bottom_boundary = green_row_indices[-1] 

# 3. Header Row Detection (just above top_boundary)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
header_region = gray[:top_boundary, :]

_, binary_header = cv2.threshold(
    header_region, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU
)
h_proj_header = np.sum(binary_header, axis=1)

header_bottom = 0
for i in range(len(h_proj_header) - 1, 0, -1):
    if h_proj_header[i] > 40:
        header_bottom = i
        break

# 4. Adaptive Thresholding in the table region
table_region = gray[top_boundary:bottom_boundary, :]
thresh_table = cv2.adaptiveThreshold(
    table_region,
    255,
    cv2.ADAPTIVE_THRESH_MEAN_C,
    cv2.THRESH_BINARY_INV,
    11,
    3
)

#kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 40))
#cleaned = cv2.morphologyEx(thresh_table, cv2.MORPH_OPEN, kernel)

# 5. Hough Lines to find vertical lines (using the filtered 'cleaned' image)
lines = cv2.HoughLinesP(
    thresh_table,
    1,
    np.pi / 180,
    threshold=tr1,
    minLineLength=linelength1,
    maxLineGap=linegap1
)
vertical_lines = []
if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]
        if abs(x2 - x1) < 5:
            vertical_lines.append((x1, top_boundary, x2, top_boundary))

# 6. Draw vertical lines on the image
for x1, y1, x2, y2 in vertical_lines:
    cv2.line(img, (x1, top_boundary), (x2, bottom_boundary+20), (100, 100, 100), 2)


# Top boundary (green)
height, width = img.shape[:2]
cv2.line(img, (0, top_boundary), (width, top_boundary), (0, 255, 0), 2)

# Bottom boundary (green)
cv2.line(img, (0, bottom_boundary), (width, bottom_boundary), (0, 255, 0), 2)
# Crop the image so that it ends at bottom_boundary + 40
crop_bottom = bottom_boundary + 40
crop_bottom = min(crop_bottom, img.shape[0])
new_width = int(img.shape[1] * 0.58)  # keep left 58% of the image
img_cropped = img[:crop_bottom, :new_width]

# 7. Convert back to PIL and save
output_pil = Image.fromarray(cv2.cvtColor(img_cropped, cv2.COLOR_BGR2RGB))
output_pil.save(output_path)

# %% [markdown]
# ### Adding lines to PDFs 2023

# %%
all_pdfs = [f for f in os.listdir("PDFs") if f.endswith(".pdf")]
pdfs_2023 = [f for f in all_pdfs if "_23_W" in f]

sorted_pdfs = sorted(pdfs_2023, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

# Limit to the top 3 sorted PDFs if needed
# sorted_pdfs = sorted_pdfs[0:3]

for pdf in sorted_pdfs:
    input_pdf = os.path.join("PDFs_2023", pdf)
    output_img = os.path.join("PDFs_Lines_2023", f"Lines_{pdf.replace('.pdf','')}_page3.png")
    enhance_table_lines_from_pdf_hq(input_pdf,
                                    output_img,
                                    h1=40, s1=0, v1=210,
                                    h2=50, s2=30, v2=255,
                                    tr1=1400,
                                    linelength1=79,
                                    linegap1=50,
                                    toler1 = 10,
                                    page_number=3,
                                    dpi=600)

# %% [markdown]
# ### Adding lines to PDFs 2024

# %%
import shutil

all_pdfs = [f for f in os.listdir("PDFs") if f.endswith(".pdf")]
pdfs_2024 = [f for f in all_pdfs if "_24_W" in f]

sorted_pdfs = sorted(pdfs_2024, key=lambda x: int(re.search(r'_W(\d+)\.pdf$', x).group(1)))

print("Sorted PDFs for 2024:", sorted_pdfs)

for pdf in sorted_pdfs:
    input_pdf = os.path.join("PDFs_2024", pdf)
    output_img = os.path.join("PDFs_Lines_2024", f"Lines_{pdf.replace('.pdf','')}_page3.png")
    enhance_table_lines_from_pdf_hq(input_pdf,
                                    output_img,
                                    h1=40, s1=0, v1=210,
                                    h2=50, s2=30, v2=255,
                                    tr1=1400,
                                    linelength1=79,
                                    linegap1=50,
                                    toler1 = 10,
                                    page_number=3,
                                    dpi=600)
# Out:
# Sorted PDFs for 2024: ['Nigeria_04_Jan_24_W1.pdf', 'Nigeria_11_Jan_24_W2.pdf', 'Nigeria_18_Jan_24_W3.pdf', 'Nigeria_25_Jan_24_W4.pdf', 'Nigeria_01_Feb_24_W5.pdf', 'Nigeria_08_Feb_24_W6.pdf', 'Nigeria_15_Feb_24_W7.pdf', 'Nigeria_22_Feb_24_W8.pdf', 'Nigeria_29_Feb_24_W9.pdf', 'Nigeria_07_Mar_24_W10.pdf', 'Nigeria_14_Mar_24_W11.pdf', 'Nigeria_21_Mar_24_W12.pdf', 'Nigeria_28_Mar_24_W13.pdf', 'Nigeria_04_Apr_24_W14.pdf', 'Nigeria_11_Apr_24_W15.pdf', 'Nigeria_18_Apr_24_W16.pdf', 'Nigeria_25_Apr_24_W17.pdf', 'Nigeria_02_May_24_W18.pdf', 'Nigeria_09_May_24_W19.pdf', 'Nigeria_16_May_24_W20.pdf', 'Nigeria_23_May_24_W21.pdf', 'Nigeria_30_May_24_W22.pdf', 'Nigeria_06_Jun_24_W23.pdf', 'Nigeria_13_Jun_24_W24.pdf', 'Nigeria_20_Jun_24_W25.pdf', 'Nigeria_27_Jun_24_W26.pdf', 'Nigeria_04_Jul_24_W27.pdf', 'Nigeria_11_Jul_24_W28.pdf', 'Nigeria_18_Jul_24_W29.pdf', 'Nigeria_25_Jul_24_W30.pdf', 'Nigeria_01_Aug_24_W31.pdf', 'Nigeria_08_Aug_24_W32.pdf', 'Nigeria_15_Aug_24_W33.pdf', 'Nigeria_22_Aug_24_W34.pdf', 'Nigeria_29_Aug_24_W35.pdf', 'Nigeria_05_Sep_24_W36.pdf', 'Nigeria_12_Sep_24_W37.pdf', 'Nigeria_19_Sep_24_W38.pdf', 'Nigeria_26_Sep_24_W39.pdf', 'Nigeria_03_Oct_24_W40.pdf', 'Nigeria_10_Oct_24_W41.pdf', 'Nigeria_14_Oct_24_W42.pdf', 'Nigeria_21_Oct_24_W43.pdf', 'Nigeria_28_Oct_24_W44.pdf', 'Nigeria_04_Nov_24_W45.pdf', 'Nigeria_11_Nov_24_W46.pdf', 'Nigeria_18_Nov_24_W47.pdf', 'Nigeria_25_Nov_24_W48.pdf', 'Nigeria_02_Dec_24_W49.pdf', 'Nigeria_09_Dec_24_W50.pdf', 'Nigeria_16_Dec_24_W51.pdf', 'Nigeria_23_Dec_24_W52.pdf']

# %% [markdown]
# # Google AI LLMs

# %%
pip install google-generativeai

# %%
pip install google.genai

# %%
from google import genai
from google.genai import types
import PIL.Image

load_dotenv()

image = PIL.Image.open('PDFs_Lines_Test/Lines_Nigeria_21_Mar_24_W12_page3.png')

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["What is this image?", image])

print(response.text)
# Out:
# The image is a table titled "Lassa Fever Situation Report" showing the weekly and cumulative number of suspected and confirmed cases for 2024. The data is broken down by state and includes information on suspected cases, confirmed cases, trend, probable cases among healthcare workers (HCW), and deaths. The table covers Epi Week 12 of 2024 and the cumulative data for weeks 1-12.

# %% [markdown]
# ## Option 1 - outputting CSV-formatted text

# %%
import os
import glob
from dotenv import load_dotenv
from google import genai
from PIL import Image

# Load the API key from the .env file
load_dotenv()

# Configure the Gemini client with your API key
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

# Define the prompt that instructs the model how to extract the table data.
prompt_template = """
The provided image contains a table with a section labeled "Current Week". Your task is to extract the data from this section only and ignore any cumulative columns.
The "Current Week" section has the following columns in this exact left-to-right order:
1. States
2. Suspected
3. Confirmed
4. Trend
5. Probable
6. HCW*
7. Deaths (Confirmed Cases)

Extract the numbers (or values) located under each column header. Return the results as a CSV-formatted table where:
- The first row contains the headers exactly as listed above.
- Each subsequent row corresponds to a State.
- The last row is for the "Total" for all States.
Ensure that all columns are present in the output, even if some cells are blank.
Output the table in the same column order as given above.
"""

# Folder containing the PNG images
image_folder = "PDFs_Lines_Test"

# Get list of PNG images from the folder
image_paths = glob.glob(os.path.join(image_folder, "*.png"))

if not image_paths:
    print(f"No PNG images found in the folder '{image_folder}'. Please check the folder name and path.")
else:
    for image_path in image_paths:
        print("Processing image:", image_path)
        
        # Open the image using Pillow
        try:
            image = Image.open(image_path)
        except Exception as e:
            print(f"Error opening image {image_path}: {e}")
            continue

        # Call the Gemini model. We send the prompt along with the image as context.
        # (Depending on the API, the image can be passed as part of the contents list.)
        try:
            response = client.models.generate_content(
                model="gemini-2.0-flash",
                # Pass a list containing the prompt and the image.
                # (The library is designed to accept multiple contents; if not, you may need to adapt this.)
                contents=[prompt_template, image]
            )
        except Exception as e:
            print(f"Error during API call for image {image_path}: {e}")
            continue

        # Print the extracted table data
        print("Extracted table data:")
        print(response.text)
        print("-" * 80)

# %% [markdown]
# ## Option 2 - using structured JSON outputs

# %%
import os
import glob
from dotenv import load_dotenv
from google import genai
from PIL import Image
from pydantic import BaseModel, Field

# Load the API key from the .env file
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY is not set in your .env file. Please add it and restart the notebook.")

# Initialize the Gemini client with your API key
client = genai.Client(api_key=api_key)

# Define the Pydantic model for one row of the table.
# We use Field aliases so that the JSON keys match the column names exactly.
class TableRow(BaseModel):
    States: str = Field(..., alias="States")
    Suspected: str = Field(..., alias="Suspected")
    Confirmed: str = Field(..., alias="Confirmed")
    Trend: str = Field(..., alias="Trend")
    Probable: str = Field(..., alias="Probable")
    HCW: str = Field(..., alias="HCW*")
    Deaths: str = Field(..., alias="Deaths (Confirmed Cases)")

# Define the prompt with instructions to extract JSON formatted output.
prompt_template = """
The provided image contains a table with a section labeled "Current Week". Your task is to extract the data from this section only and ignore any cumulative columns.
The "Current Week" section has the following columns in this exact left-to-right order:
1. States
2. Suspected
3. Confirmed
4. Trend
5. Probable
6. HCW*
7. Deaths (Confirmed Cases)

Extract the values located under each column header and return the results in JSON format.
Return a JSON list of objects, where each object corresponds to one row of the table.
Each object must have the following keys (exactly in this order):
"States", "Suspected", "Confirmed", "Trend", "Probable", "HCW*", "Deaths (Confirmed Cases)"
Include one object per state, and the last object should correspond to the "Total" row.
Ensure that all keys are present in every object, even if some values are blank.
Output the JSON in valid format.
"""

# Folder containing the PNG images
image_folder = "PDFs_Lines_Test"  # Adjust this to your local folder name

# Get list of PNG images from the folder
image_paths = glob.glob(os.path.join(image_folder, "*.png"))
if not image_paths:
    print(f"No PNG images found in the folder '{image_folder}'. Please check the folder name and path.")
else:
    for image_path in image_paths:
        print("Processing image:", image_path)
        
        # Open the image using Pillow
        try:
            image = Image.open(image_path)
        except Exception as e:
            print(f"Error opening image {image_path}: {e}")
            continue

        # Call the Gemini model using structured JSON output.
        try:
            response = client.models.generate_content(
                model="gemini-2.0-flash",
                contents=[prompt_template, image],
                config={
                    "response_mime_type": "application/json",
                    "response_schema": list[TableRow],
                }
            )
        except Exception as e:
            print(f"Error during API call for image {image_path}: {e}")
            continue

        # Print the raw JSON response text
        print("Raw JSON response:")
        print(response.text)
        
        # Parse the response into TableRow objects (if supported)
        try:
            # The client library may provide a parsed attribute containing Pydantic objects.
            table_rows = response.parsed  # Expected to be a list of TableRow objects.
            print("Extracted Table Data (parsed):")
            for row in table_rows:
                # Use .dict(by_alias=True) to output keys as specified in the schema.
                print(row.dict(by_alias=True))
        except Exception as e:
            print(f"Error parsing response for image {image_path}: {e}")
        print("-" * 80)

# %% [markdown]
# ## Option 3 - same as option 2 but saving combined json as CSV

# %%
import os
import glob
import csv
from dotenv import load_dotenv
from google import genai
from PIL import Image
from pydantic import BaseModel, Field

# Load the API key from the .env file
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY is not set in your .env file. Please add it and restart the notebook.")

# Initialize the Gemini client with your API key
client = genai.Client(api_key=api_key)

# Define the Pydantic model for one row of the table.
# Field aliases are used so that the JSON keys match the column names exactly.
class TableRow(BaseModel):
    States: str = Field(..., alias="States")
    Suspected: str = Field(..., alias="Suspected")
    Confirmed: str = Field(..., alias="Confirmed")
    Trend: str = Field(..., alias="Trend")
    Probable: str = Field(..., alias="Probable")
    HCW: str = Field(..., alias="HCW*")
    Deaths: str = Field(..., alias="Deaths (Confirmed Cases)")

# Define the prompt with instructions to extract JSON formatted output.
prompt_template = """
The provided image contains a table with a section labeled "Current Week". Your task is to extract the data from this section only and ignore any cumulative columns.
The "Current Week" section has the following columns in this exact left-to-right order:
1. States
2. Suspected
3. Confirmed
4. Trend
5. Probable
6. HCW*
7. Deaths (Confirmed Cases)

Extract the values located under each column header and return the results in JSON format.
Return a JSON list of objects, where each object corresponds to one row of the table.
Each object must have the following keys (exactly in this order):
"States", "Suspected", "Confirmed", "Trend", "Probable", "HCW*", "Deaths (Confirmed Cases)".
"Trend" column may contain either blank cells, or one of two types of triangles: ▲ (Up, red triangle) or ▼ (Down, green triangle). You should input either "Up" or "Down" as a value.
Include one object per state, and the last object should correspond to the "Total" row.
Ensure that all keys are present in every object, even if some values are blank.
Output the JSON in valid format.
"""

# Folder containing the PNG images
image_folder = "PDFs_Lines_Test"  # Adjust this to your local folder name

# Get list of PNG images from the folder
image_paths = glob.glob(os.path.join(image_folder, "*.png"))
if not image_paths:
    print(f"No PNG images found in the folder '{image_folder}'. Please check the folder name and path.")
else:
    # Define the CSV header in the exact order we expect:
    fieldnames = [
        "States",
        "Suspected",
        "Confirmed",
        "Trend",
        "Probable",
        "HCW*",
        "Deaths (Confirmed Cases)"
    ]
    
    for image_path in image_paths:
        print("Processing image:", image_path)
        
        # Open the image using Pillow
        try:
            image = Image.open(image_path)
        except Exception as e:
            print(f"Error opening image {image_path}: {e}")
            continue

        # Call the Gemini model using structured JSON output.
        try:
            response = client.models.generate_content(
                model="gemini-2.0-flash",
                contents=[prompt_template, image],
                config={
                    "response_mime_type": "application/json",
                    "response_schema": list[TableRow],
                }
            )
        except Exception as e:
            print(f"Error during API call for image {image_path}: {e}")
            continue

        # Print the raw JSON response text for debugging
        print("Raw JSON response:")
        print(response.text)
        
        # Parse the response into TableRow objects (if supported)
        try:
            table_rows = response.parsed  # Expected to be a list of TableRow objects.
            print("Extracted Table Data (parsed):")
            for row in table_rows:
                print(row.dict(by_alias=True))
        except Exception as e:
            print(f"Error parsing response for image {image_path}: {e}")
            continue
        
        # Create a CSV filename based on the image filename and save into the CSV_LF folder
        base_filename = os.path.splitext(os.path.basename(image_path))[0]
        csv_filename = os.path.join("CSV_LF", f"{base_filename}.csv")
        
        # Write the extracted data to CSV
        try:
            with open(csv_filename, mode="w", newline="", encoding="utf-8") as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                for row in table_rows:
                    # Convert each TableRow to a dict using aliases to preserve key names.
                    writer.writerow(row.dict(by_alias=True))
            print(f"CSV file saved as: {csv_filename}")
        except Exception as e:
            print(f"Error writing CSV for image {image_path}: {e}")
        
        print("-" * 80)

# %% [markdown]
# ## Option 4 - 2 API calls per image to ensure accuracy

# %%
import os
import glob
import csv
from dotenv import load_dotenv
from google import genai
from PIL import Image
from pydantic import BaseModel, Field

# Load the API key from the .env file
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY is not set in your .env file. Please add it and restart the notebook.")

# Initialize the Gemini client with your API key
client = genai.Client(api_key=api_key)

# Define the Pydantic model for one row of the table.
class TableRow(BaseModel):
    States: str = Field(..., alias="States")
    Suspected: str = Field(..., alias="Suspected")
    Confirmed: str = Field(..., alias="Confirmed")
    Trend: str = Field(..., alias="Trend")
    Probable: str = Field(..., alias="Probable")
    HCW: str = Field(..., alias="HCW*")
    Deaths: str = Field(..., alias="Deaths (Confirmed Cases)")

# Define the prompt with instructions to extract JSON formatted output.
prompt_template = """
The provided image contains a table with a section labeled "Current Week". Your task is to extract the data from this section only.
The "Current Week" section has the following columns in this exact left-to-right order:
1. States
2. Suspected
3. Confirmed
4. Trend
5. Probable
6. HCW*
7. Deaths (Confirmed Cases)

Extract the values located under each column header and return the results in JSON format.
Return a JSON list of objects, where each object corresponds to one row of the table.

Each object must have the following keys (exactly in this order):
"States", "Suspected", "Confirmed", "Trend", "Probable", "HCW*", "Deaths (Confirmed Cases)".

"States" corresponds to the states of Nigeria: Ondo, Edo, Bauchi, Taraba, Benue, Ebonyi, Kogi, Kaduna, Plateau, Enugu, Cross River, Rivers, Delta, Nasarawa, Anambra, Gombe, Niger, Imo, Jigawa, Bayelsa, Adamawa, Fct, Katsina, Kano, Oyo, Lagos, Ogun, Yobe, Sokoto, Kebbi, Zamfara, Akwa Ibom, Ekiti, Kwara, Borno, Osun, Abia. The last row should correspond to the "Total" for all states.
If a row is blank and has no value in "States" column, you should omit it.

"Trend" column may contain either blank cells, or one of two types of triangles: ▲ (Up, red triangle) or ▼ (Down, green triangle). You should input either "Up" or "Down" as a value.

Include one object per state, and the last object should correspond to the "Total" row.
Ensure that all keys are present in every object, even if some values are blank.
Output the JSON in valid format.
"""

# Folder containing the PNG images
image_folder = "PDFs_Lines_Test"  # Adjust this to your local folder name

# Get list of PNG images from the folder
image_paths = glob.glob(os.path.join(image_folder, "*.png"))
if not image_paths:
    print(f"No PNG images found in the folder '{image_folder}'. Please check the folder name and path.")
else:
    # Define the CSV header in the exact order we expect:
    fieldnames = [
        "States",
        "Suspected",
        "Confirmed",
        "Trend",
        "Probable",
        "HCW*",
        "Deaths (Confirmed Cases)"
    ]
    
    for image_path in image_paths:
        print("Processing image:", image_path)
        
        # Open the image using Pillow
        try:
            image = Image.open(image_path)
        except Exception as e:
            print(f"Error opening image {image_path}: {e}")
            continue

        # Process the image twice
        responses = []
        for i in range(2):
            try:
                response = client.models.generate_content(
                    model="gemini-2.0-flash",
                    contents=[prompt_template, image],
                    config={
                        "response_mime_type": "application/json",
                        "response_schema": list[TableRow],
                    }
                )
                responses.append(response)
            except Exception as e:
                print(f"Error during API call for image {image_path} on iteration {i+1}: {e}")
                responses = []
                break  # Skip to next image if there's an error

        if len(responses) != 2:
            print("Skipping image due to API call errors.")
            continue

        # Parse the responses into lists of TableRow objects
        try:
            table_rows_1 = responses[0].parsed  # List[TableRow]
            table_rows_2 = responses[1].parsed  # List[TableRow]
        except Exception as e:
            print(f"Error parsing responses for image {image_path}: {e}")
            continue

        # Convert both lists into lists of dictionaries
        dict_rows_1 = [row.dict(by_alias=True) for row in table_rows_1]
        dict_rows_2 = [row.dict(by_alias=True) for row in table_rows_2]

        # Compare the two outputs
        if dict_rows_1 == dict_rows_2:
            print("Both outputs are identical. Saving CSV.")
            # Create a CSV filename based on the image filename
            base_filename = os.path.splitext(os.path.basename(image_path))[0]
            csv_filename = os.path.join("CSV_LF", f"{base_filename}.csv")
            # Write the extracted data to CSV
            try:
                with open(csv_filename, mode="w", newline="", encoding="utf-8") as csvfile:
                    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                    writer.writeheader()
                    for row in dict_rows_1:
                        writer.writerow(row)
                print(f"CSV file saved as: {csv_filename}")
            except Exception as e:
                print(f"Error writing CSV for image {image_path}: {e}")
        else:
            print("Outputs differ between iterations for image:", image_path)
            # Identify differing rows
            min_len = min(len(dict_rows_1), len(dict_rows_2))
            differences_found = False
            
            for i in range(min_len):
                if dict_rows_1[i] != dict_rows_2[i]:
                    differences_found = True
                    print(f"Difference in row {i+1}:")
                    print("Iteration 1:", dict_rows_1[i])
                    print("Iteration 2:", dict_rows_2[i])
            
            # Check for any extra rows
            if len(dict_rows_1) > min_len:
                differences_found = True
                print("Additional rows in iteration 1:")
                for i in range(min_len, len(dict_rows_1)):
                    print(f"Row {i+1}:", dict_rows_1[i])
            if len(dict_rows_2) > min_len:
                differences_found = True
                print("Additional rows in iteration 2:")
                for i in range(min_len, len(dict_rows_2)):
                    print(f"Row {i+1}:", dict_rows_2[i])
            
            if not differences_found:
                print("No individual row differences were found, despite overall inequality.")
            
            print("Skipping CSV saving for this image due to inconsistency.")
        
        print("-" * 80)
# Out:
# Processing image: PDFs_Lines_Test/Lines_Nigeria_16_Dec_24_W51_page3.png
# Both outputs are identical. Saving CSV.
# CSV file saved as: CSV_LF/Lines_Nigeria_16_Dec_24_W51_page3.csv
# --------------------------------------------------------------------------------
# Processing image: PDFs_Lines_Test/Lines_Nigeria_29_Aug_24_W35_page3.png
# Both outputs are identical. Saving CSV.
# CSV file saved as: CSV_LF/Lines_Nigeria_29_Aug_24_W35_page3.csv
# --------------------------------------------------------------------------------
# Processing image: PDFs_Lines_Test/Lines_Nigeria_27_Jun_24_W26_page3.png
# Both outputs are identical. Saving CSV.
# CSV file saved as: CSV_LF/Lines_Nigeria_27_Jun_24_W26_page3.csv
# --------------------------------------------------------------------------------
# Processing image: PDFs_Lines_Test/Lines_Nigeria_21_Mar_24_W12_page3.png
# Both outputs are identical. Saving CSV.
# CSV file saved as: CSV_LF/Lines_Nigeria_21_Mar_24_W12_page3.csv
# --------------------------------------------------------------------------------
# Processing image: PDFs_Lines_Test/Lines_Nigeria_04_Jan_24_W1_page3.png
# Both outputs are identical. Saving CSV.
# CSV file saved as: CSV_LF/Lines_Nigeria_04_Jan_24_W1_page3.csv
# --------------------------------------------------------------------------------

# %%
# Out:
# 1880

# %% [markdown]
# # Google Vision

# %%
# Out:
# 0.5787878787878787

# %%
import io
import os
from google.cloud import vision
from google.cloud.vision_v1 import types
import pandas as pd
from dotenv import load_dotenv

load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
import io
import os
from google.cloud import vision
from google.cloud.vision_v1 import types
import pandas as pd
from dotenv import load_dotenv

load_dotenv()  # Load environment variables from .env file

# --- Configuration ---
IMAGE_FOLDER = 'PDFs_Lines_Test'  # Folder containing your PNG images.  Relative path is OK.


def detect_text_and_tables(image_path):
    """Detects text and attempts basic table structure extraction from an image.

    Args:
        image_path: Path to the image file.

    Returns:
        A tuple: (extracted_text, table_data)
        - extracted_text:  Raw text extracted from the image (string).
        - table_data: A list of lists representing the extracted table data.
                      Each inner list represents a row.  Returns None if no table
                      structure is reasonably detected.
    """
    client = vision.ImageAnnotatorClient()

    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    # Perform text detection (OCR)
    response = client.document_text_detection(image=image)
    extracted_text = response.full_text_annotation.text
    
    # --- Attempt Table Extraction ---
    table_data = extract_table_data(response)  # Use the helper function

    return extracted_text, table_data

def extract_table_data(response):
    """
    Extracts table data from the Google Cloud Vision API response. This uses
    block structure, paragraph and word structure, row and column detection.

    Args:
        response:  The full response from client.document_text_detection().

    Returns:
        A list of lists representing the extracted table data, or None if
        no table-like structure is found.
    """
    blocks = response.full_text_annotation.pages[0].blocks
    
    # 1. Organize bounding box information for efficient lookup.
    bounding_boxes = {}  # Key: (page, block, paragraph, word), Value: BoundingBox
    for page_num, page in enumerate(response.full_text_annotation.pages):
        for block_num, block in enumerate(page.blocks):
            for paragraph_num, paragraph in enumerate(block.paragraphs):
                for word_num, word in enumerate(paragraph.words):
                    bounding_boxes[(page_num, block_num, paragraph_num, word_num)] = word.bounding_box
    
    #Helper function to get bounding vertices for paragraphs
    def get_paragraph_bounds(paragraph):
      """Extracts bounding box vertices from a paragraph."""
      min_x = float('inf')
      min_y = float('inf')
      max_x = float('-inf')
      max_y = float('-inf')

      for word in paragraph.words:
        for symbol in word.symbols:
          for vertex in symbol.bounding_box.vertices:
            min_x = min(min_x, vertex.x)
            min_y = min(min_y, vertex.y)
            max_x = max(max_x, vertex.x)
            max_y = max(max_y, vertex.y)
      return min_x, min_y, max_x, max_y

    # 2. Create data structure for paragraphs (rows)
    paragraphs_data = []
    
    for page_num, page in enumerate(response.full_text_annotation.pages):
      for block_num, block in enumerate(page.blocks):
          for paragraph_num, paragraph in enumerate(block.paragraphs):
            min_x, min_y, max_x, max_y = get_paragraph_bounds(paragraph) # Get Paragraph bounds
            paragraph_text = ""
            for word in paragraph.words:
                for symbol in word.symbols:
                    paragraph_text += symbol.text
            paragraphs_data.append({
                'text': paragraph_text,
                'min_x': min_x,
                'min_y': min_y,
                'max_x': max_x,
                'max_y': max_y,
            })
        
    # 3. Sort paragraphs_data by 'min_y' (top to bottom), then by 'min_x' (left to right)
    paragraphs_data.sort(key=lambda p: (p['min_y'], p['min_x']))
    
    
    #4. Row detection
    
    rows = []
    current_row = []
    if paragraphs_data:
        # Initialize with the y-coordinate of the first paragraph
        current_row_y_center = paragraphs_data[0]['min_y']
        row_height_estimate = paragraphs_data[0]['max_y'] - paragraphs_data[0]['min_y'] #initial height estimation
        
        tolerance_y = row_height_estimate * 0.5 # Allow the row height to vary 
        
        for paragraph in paragraphs_data:
            paragraph_y_center = (paragraph['min_y'] + paragraph['max_y']) / 2
            
            if abs(paragraph_y_center - current_row_y_center) <= tolerance_y :
                current_row.append(paragraph)
                
            else:
                # Sort current row by x coordinate before saving it
                current_row.sort(key=lambda p: p['min_x'])
                rows.append(current_row)
                current_row = [paragraph]  # start new row
                current_row_y_center = paragraph_y_center  #update Y of current row
                row_height_estimate = paragraph['max_y'] - paragraph['min_y']
                tolerance_y = row_height_estimate * 0.5 #update the tolerance
    
    # Append the last row if it's not empty
    if current_row:
        current_row.sort(key=lambda p: p['min_x'])
        rows.append(current_row)
        
    
    # 5. Convert to list of lists (text only) for the table
    table_data = []
    for row in rows:
        row_data = [p['text'] for p in row]
        table_data.append(row_data)
    
    if not table_data:
        return None  # No table-like structure found
    return table_data


def process_images(image_folder):
    """Processes all PNG images in a folder, extracting text and tables."""

    all_results = {}  # Store results for each image

    for filename in os.listdir(image_folder):
        if filename.lower().endswith('.png'):
            image_path = os.path.join(image_folder, filename)
            print(f"Processing: {filename}")

            extracted_text, table_data = detect_text_and_tables(image_path)

            all_results[filename] = {
                'text': extracted_text,
                'table': table_data
            }

            # Print results (optional, for immediate feedback)
            print(f"Extracted Text:\n{extracted_text}\n")

            if table_data:
                print("Extracted Table:")
                df = pd.DataFrame(table_data)
                print(df.to_string()) #Use Panda for better printing
            else:
                print("No table found.")
            print("-" * 40)

    return all_results



# --- Main Execution ---
if __name__ == '__main__':
    results = process_images(IMAGE_FOLDER)

    # --- Post-Processing (Example: Saving results to files) ---
    # You can now further process the 'results' dictionary.  For example:

    """ for filename, data in results.items():
        # Save extracted text to a .txt file
        text_filename = os.path.join(IMAGE_FOLDER, f"{filename.split('.')[0]}_text.txt")
        with open(text_filename, 'w', encoding='utf-8') as f:
            f.write(data['text'])

        # Save table data to a .csv file (if a table was found)
        if data['table']:
            table_filename = os.path.join(IMAGE_FOLDER, f"{filename.split('.')[0]}_table.csv")
            df = pd.DataFrame(data['table'])
            df.to_csv(table_filename, index=False, header=False)  # Save without row indices or headers """

# %%
from dotenv import load_dotenv
import io
import os
import cv2
import numpy as np
from google.cloud import vision
from google.cloud.vision_v1 import types
import pandas as pd

# --- Load Environment Variables ---
load_dotenv()

# --- Configuration ---
IMAGE_FOLDER = 'PDFs_Lines_Test'  # Your image folder

def detect_table_structure(image_path):
    """Detects table structure (lines) using OpenCV, handling no-line cases.

    Args:
        image_path: Path to the image.

    Returns:
        A tuple: (horizontal_lines, vertical_lines, image_gray).
        - horizontal_lines:  Detected horizontal lines or an empty list if none.
        - vertical_lines: Detected vertical lines or an empty list if none.
        - image_gray: The grayscale image (or None if loading failed).
    """
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not open or read image at {image_path}")

    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # --- Thresholding (Binarization) ---
    thresh = cv2.adaptiveThreshold(~image_gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 15, -2)

    # --- Horizontal Line Detection ---
    horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (25, 1))
    horizontal_lines = cv2.erode(thresh, horizontal_kernel, iterations=3)
    horizontal_lines = cv2.dilate(horizontal_lines, horizontal_kernel, iterations=3)

    # --- Vertical Line Detection ---
    vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 25))
    vertical_lines = cv2.erode(thresh, vertical_kernel, iterations=3)
    vertical_lines = cv2.dilate(vertical_lines, vertical_kernel, iterations=3)
    
    return horizontal_lines, vertical_lines, image_gray


def get_table_cells(horizontal_lines, vertical_lines, image_gray):
    """
       Gets the bounding box coordinates of table cells based on detected lines.
       Creates and empty table of dimensions as detected by number of intersections

    Args:
        horizontal_lines:  Result from detect_table_structure.
        vertical_lines: Result from detect_table_structure.
        image_gray: Grayscale image.

    Returns:
        A list of lists representing the table cells' bounding box coordinates,
        where each inner list represents a row, and each element in the inner
        list is a tuple: (x1, y1, x2, y2).
    """

    # --- Combine Lines and Find Contours ---
    table_lines = cv2.addWeighted(horizontal_lines, 0.5, vertical_lines, 0.5, 0.0)
    table_lines = cv2.erode(~table_lines, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3)), iterations=1)
    (T, thresh) = cv2.threshold(table_lines, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if len(contours) == 2 else contours[1]  # Handle different OpenCV versions

    # --- Get Bounding Boxes of Cells ---
    bounding_boxes = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        bounding_boxes.append((x, y, x + w, y + h))
    
    # --- Sort Bounding Boxes (Top-to-Bottom, Then Left-to-Right) ---
    bounding_boxes.sort(key=lambda bbox: (bbox[1], bbox[0])) # Sort by y first, x second
    
    # --- Determine Table Dimensions ---
    # Estimate number of columns and rows based on lines, not contours
    #This is more accurate, and then we map extracted contours to the empty table
    
    lines_v = cv2.HoughLinesP(vertical_lines, 1, np.pi / 180, 200, minLineLength=20, maxLineGap=15)
    lines_h = cv2.HoughLinesP(horizontal_lines, 1, np.pi / 180, 200, minLineLength=20, maxLineGap=15)

    #Count the number of lines to estimate columns and rows.
    if lines_v is not None:
        num_columns = len(lines_v)
    else:
        num_columns = 0  # No Vertical Lines

    if lines_h is not None:
        num_rows = len(lines_h)
    else:
        num_rows = 0
    
    #Create Empty Table Structure of cells
    if (num_rows > 0) and (num_columns > 0):
        table_cells = [[None for _ in range(num_columns)] for _ in range(num_rows)]
        # --- Map Bounding Boxes to Cells ---
        # Fill in the table structure. We iterate the extracted rectangles and insert
        #them into an appropriate cell.
        
        for x1, y1, x2, y2 in bounding_boxes:
            cell_assigned = False
            for i in range(num_rows):
                for j in range(num_columns):
                    # Check if we already have a box in table cell
                    if table_cells[i][j] is None:
                        # Check if current coordinates intersect with the area that a particular table cell would cover
                        # Get Line coordinates (extrapolate a bit to not miss edge cases)
                        y_start = lines_h[i][0][1] - 5 if lines_h is not None else y1 # use y from the box as backup
                        y_end = lines_h[i+1][0][1] + 5 if i+1<len(lines_h) and lines_h is not None else y2  # use y from the box as backup
                        
                        x_start = lines_v[j][0][0] - 5 if lines_v is not None else x1 # use x from the box as backup
                        x_end = lines_v[j+1][0][0] + 5 if j+1 < len(lines_v) and lines_v is not None else x2 # use x from the box as backup
                        
                        
                        # Check for overlap
                        if (x1 >= x_start and x2 <= x_end and
                           y1 >= y_start and y2 <= y_end):
                            
                            #Store Bounding box into that cell.
                            table_cells[i][j] = (x1, y1, x2, y2)
                            cell_assigned = True
                            break   #exit column
                if cell_assigned:
                    break   # exit row
    else:
        table_cells = [] #return empty table if error in HoughLines

    return table_cells

def extract_text_from_cells(table_cells, image_gray, client):
    """Extracts text from each cell using Google Cloud Vision API.

    Args:
        table_cells: The list of lists representing cell bounding boxes.
        image_gray:  The grayscale image.
        client: The Google Cloud Vision API client.

    Returns:
        A list of lists representing the extracted text from each cell.
    """
    table_text = []

    for row_cells in table_cells:
        row_text = []
        for x1, y1, x2, y2 in row_cells:
            if (x1, y1, x2, y2) is not None:
                # Crop the cell region from the grayscale image
                cell_image = image_gray[y1:y2, x1:x2]

                # Convert the OpenCV image to bytes (required by Vision API)
                _, encoded_image = cv2.imencode('.png', cell_image)
                content = encoded_image.tobytes()
                image = types.Image(content=content)

                # Perform OCR on the cell image
                response = client.document_text_detection(image=image)
                cell_text = response.full_text_annotation.text if response.full_text_annotation else ""

                row_text.append(cell_text)
            else:
                row_text.append("") #handle empty cells
        table_text.append(row_text)

    return table_text


def detect_text_and_tables(image_path):
    """Main function to detect text and tables, handling errors."""
    try:
        horizontal_lines, vertical_lines, image_gray = detect_table_structure(image_path)
        table_cells = get_table_cells(horizontal_lines, vertical_lines, image_gray)

        client = vision.ImageAnnotatorClient()
        table_data = extract_text_from_cells(table_cells, image_gray, client)

        # Extract all text from the image (for the 'extracted_text' part)
        with io.open(image_path, 'rb') as image_file:
            content = image_file.read()
        image = types.Image(content=content)
        response = client.document_text_detection(image=image)
        extracted_text = response.full_text_annotation.text

        return extracted_text, table_data

    except ValueError as ve:
        print(f"ValueError: {ve}")
        return None, None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None, None


def process_images(image_folder):
    """Processes images and extracts text/tables."""
    all_results = {}

    for filename in os.listdir(image_folder):
        if filename.lower().endswith('.png'):
            image_path = os.path.join(image_folder, filename)
            print(f"Processing: {filename}")

            try:  # Add a try-except block here
                extracted_text, table_data = detect_text_and_tables(image_path)
            except TypeError as e:
                print(f"TypeError occurred: {e}")
                import pdb; pdb.set_trace()  # Add this line!
                extracted_text, table_data = None, None #placeholder to avoid further errors.

            if extracted_text is not None:
                all_results[filename] = {
                    'text': extracted_text,
                    'table': table_data
                }

                print(f"Extracted Text:\n{extracted_text}\n")
                if table_data:
                    print("Extracted Table:")
                    df = pd.DataFrame(table_data)
                    print(df.to_string())  # Use Pandas for better printing
                else:
                    print("No table found.")
                print("-" * 40)

    return all_results


if __name__ == '__main__':
    if not os.path.exists(IMAGE_FOLDER):
        os.makedirs(IMAGE_FOLDER)

    results = process_images(IMAGE_FOLDER)

    """ for filename, data in results.items():
        text_filename = os.path.join(IMAGE_FOLDER, f"{filename.split('.')[0]}_text.txt")
        with open(text_filename, 'w', encoding='utf-8') as f:
            f.write(data['text'])
        if data['table']:
            table_filename = os.path.join(IMAGE_FOLDER, f"{filename.split('.')[0]}_table.csv")
            df = pd.DataFrame(data['table'])
            df.to_csv(table_filename, index=False, header=False) """
# Out:
# Processing: Lines_Nigeria_21_Mar_24_W12_page3.png
# An unexpected error occurred: cannot unpack non-iterable NoneType object

# %%
extracted_text, table_data = detect_text_and_tables(image_path)
# Out:
# An unexpected error occurred: cannot unpack non-iterable NoneType object

# %%
results
# Out:
# {'Lines_Nigeria_21_Mar_24_W12_page3.png': {'text': 'Epi Week: 12 2024\nCumulative (Week 1 - 12)\nCases\nDeaths\nLassa Fever Situation Report\nTable 3. Weekly and Cumulative number of suspected and confirmed cases for 2024\nCurrent week: (Week 12)\nCases\nDeaths\nStates\nSuspected Confirmed Trend Probable HCW* (Confirmed Cases) Suspected Confirmed Probable HCW* (Confirmed Cases)\n1 Ondo\n60\n8\n1026\n184\n3\n13\n2 Edo\n77\n4\n1171\n178\n1\n23\n3 Bauchi\n34\n4❘ Taraba\n27\n5 Benue\n29\n352\n1\n566\n123\n3\n27\n1\n190\n95\n3\n20\n2\n999\n62\n9\n8\n00\n11\n6 Ebonyi\n17\n1\n1\n213\n43\n6\n24\n7 Kogi\n2\n1\n1\n94\n28\n1\n1\n2\n8 Kaduna\n7\n97\n15\n2\n3\n8\n9 Plateau\n9\n1\n63\n9\n10 Enugu\n1\n63\n8\n1\n11 Cross River\n12\n1\n45\n7\n1\n12 Rivers\n56\n5\n3\n13 Delta\n3\n54\n4\n2\n14 Anambra\n1\n17\n4\n1\n3\n15 Nasarawa\n37\n4\n1\n1\n16 Niger\n8\n3\nN\n17 Gombe\n25\n3\n5\n1\n18 Imo\n2\n30\n3\n1\n2\n19 Jigawa\n2\n22\n2\n1\n20 Bayelsa\n1\n14\n21 Adamawa\n1\n12\n22 Fct\n1\n42\nN N N\n2\n1\n23 Kano\n2\n45\n1\n24 Oyo\n1\n21\n1\n1\n25 Lagos\n1\n26\n1\n26 Ogun\n5\n20\n1\n1\n1\n27 Yobe\n14\n1\n1\n2\n2\n28 Kebbi\n29 Zamfara\n30 Akwa Ibom\n31 Ekiti\nN\n32 Kwara\n1\n33 Katsina\n2\n34 Borno\n1\n35 Osun\n36 Abia\n20\n135527∞\n8\nTotal\n303\n25\n0\n1\n6\n5029\n791\n17\n32\n149',
#   'table': [['LassaFeverSituationReport'],
#    ['EpiWeek:122024'],
#    ['Table3.WeeklyandCumulativenumberofsuspectedandconfirmedcasesfor2024'],
#    ['Currentweek:(Week12)', 'Cumulative(Week1-12)'],
#    ['Cases', 'Deaths', 'Cases', 'Deaths'],
#    ['States'],
#    ['SuspectedConfirmedTrendProbableHCW*(ConfirmedCases)SuspectedConfirmedProbableHCW*(ConfirmedCases)'],
#    ['1Ondo', '60', '8', '1026', '184', '3', '13'],
#    ['2Edo', '77', '4', '1171', '178', '1', '23'],
#    ['4❘Taraba',
#     '3Bauchi',
#     '5Benue',
#     '27',
#     '29',
#     '34',
#     '352',
#     '2',
#     '1',
#     '1',
#     '566',
#     '999',
#     '190',
#     '123',
#     '95',
#     '62',
#     '9',
#     '3',
#     '8',
#     '3',
#     '00',
#     '27',
#     '20',
#     '11'],
#    ['6Ebonyi', '17', '1', '1', '213', '43', '6', '24'],
#    ['7Kogi', '2', '1', '1', '94', '28', '1', '1', '2'],
#    ['8Kaduna', '7', '97', '15', '2', '3', '8'],
#    ['9Plateau', '9', '1', '63', '9'],
#    ['10Enugu', '1', '63', '8', '1'],
#    ['11CrossRiver', '12', '1', '45', '7', '1'],
#    ['12Rivers', '56', '5', '3'],
#    ['13Delta', '3', '54', '4', '2'],
#    ['14Anambra', '1', '17', '4', '1', '3'],
#    ['15Nasarawa', '37', '4', '1', '1'],
#    ['16Niger', '8', '3', 'N'],
#    ['17Gombe', '25', '3', '5', '1'],
#    ['18Imo', '2', '30', '3', '1', '2'],
#    ['19Jigawa', '2', '22', '2', '1'],
#    ['20Bayelsa'],
#    ['21Adamawa', '22Fct', '1', '1', '1', '42', '14', '12', '2', 'NNN', '1'],
#    ['23Kano', '2', '45', '1'],
#    ['24Oyo', '1', '21', '1', '1'],
#    ['25Lagos', '1', '26', '1'],
#    ['26Ogun', '5', '20', '1', '1', '1'],
#    ['27Yobe', '14', '1', '1'],
#    ['28Kebbi', '2', '2'],
#    ['30AkwaIbom',
#     '29Zamfara',
#     '32Kwara',
#     '33Katsina',
#     '34Borno',
#     '35Osun',
#     '31Ekiti',
#     '1',
#     '2',
#     '1',
#     'N',
#     '20',
#     '135527∞'],
#    ['36Abia', '8'],
#    ['Total', '303', '25', '0', '1', '6', '5029', '791', '17', '32', '149']]}}

# %% [markdown]
# # 15% left

# %%
import cv2
import numpy as np
from PIL import Image, ImageColor
import fitz  # PyMuPDF

def hex_to_hsv(hex_color):
    rgb = ImageColor.getcolor(hex_color, "RGB")
    r, g, b = [x / 255.0 for x in rgb]
    hsv = cv2.cvtColor(
        np.uint8([[[b * 255, g * 255, r * 255]]]),
        cv2.COLOR_BGR2HSV
    )[0][0]
    return hsv

def enhance_table_lines_from_pdf_hq(pdf_path, output_path, page_number=0, dpi=300):
    """
    Enhances vertical column separators and draws horizontal lines at
    top boundary, bottom boundary, and header bottom.

    Args:
        pdf_path (str): Path to the PDF.
        output_path (str): Path to save the image (use .png).
        page_number (int): Page to process (0-indexed).
        dpi (int): Resolution for rendering the PDF page.
    """
    doc = fitz.open(pdf_path)
    page = doc[page_number]

    # 1. Render the PDF page at high DPI
    pix = page.get_pixmap(dpi=dpi) 
    img_pil = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    # Convert PIL Image to OpenCV BGR
    img = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

    # 2. Convert to HSV & detect green rows
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    height, width = img.shape[:2]
    
    # We'll only check the left 15% of the page's width
    left_15_width = int(width * 0.15)

    target_hsv = hex_to_hsv("#D8EDCF")
    tolerance = 15
    lower_green = np.array([max(0, target_hsv[0] - tolerance), 50, 50])
    upper_green = np.array([min(179, target_hsv[0] + tolerance), 255, 255])
    green_mask = cv2.inRange(hsv, lower_green, upper_green)

    # Sum only the left 15% columns
    green_mask_left = green_mask[:, :left_15_width]
    h_proj_green = np.sum(green_mask_left, axis=1)
    green_row_indices = np.where(h_proj_green > 0)[0]

    if len(green_row_indices) == 0:
        print("No green rows detected.")
        return

    top_boundary = green_row_indices[0]
    bottom_boundary = green_row_indices[-1]

    # 3. Header Row Detection (just above top_boundary)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    header_region = gray[:top_boundary, :]

    # Use Otsu’s threshold for the header
    _, binary_header = cv2.threshold(
        header_region, 0, 255,
        cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU
    )
    h_proj_header = np.sum(binary_header, axis=1)

    header_bottom = 0
    for i in range(len(h_proj_header) - 1, 0, -1):
        if h_proj_header[i] > 40:
            header_bottom = i
            break

    # 4. Adaptive Thresholding in the table region
    table_region = gray[top_boundary:bottom_boundary, :]
    thresh_table = cv2.adaptiveThreshold(
        table_region,
        255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY_INV,
        11,
        3
    )

    # 5. Hough Lines to find vertical lines
    lines = cv2.HoughLinesP(thresh_table, 1, np.pi / 180,
                            threshold=775, minLineLength=10, maxLineGap=8)
    vertical_lines = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            if abs(x2 - x1) < 5:  # near-vertical
                # Adjust back to full image coordinates
                vertical_lines.append((x1, y1 + top_boundary, x2, y2 + top_boundary))

    # 6. Draw lines on the OpenCV image
    # A) Draw the vertical lines from header_bottom to bottom_boundary
    for x1, y1, x2, y2 in vertical_lines:
        cv2.line(img, (x1, header_bottom), (x2, bottom_boundary), (100, 100, 100), 1)

    # B) Draw horizontal lines at top, bottom, and header_bottom
    cv2.line(img, (0, top_boundary), (width, top_boundary), (0, 255, 0), 2)     # green
    cv2.line(img, (0, bottom_boundary), (width, bottom_boundary), (0, 255, 0), 2) # green
    cv2.line(img, (0, header_bottom), (width, header_bottom), (0, 0, 255), 2)  # red

    # 7. Convert back to PIL and save
    output_pil = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    output_pil.save(output_path)

    print(f"Saved enhanced table to: {output_path}")

# %%
for week in [1,2,3,4,12,22,26,32,42,52]:
    enhance_table_lines_from_pdf_hq(f"PDFs/W{week}.pdf", f"Lines_W{week}_boundaries.png", page_number=3, dpi=300)
# Out:
# Saved enhanced table to: Lines_W1_boundaries.png
# Saved enhanced table to: Lines_W2_boundaries.png
# Saved enhanced table to: Lines_W3_boundaries.png
# Saved enhanced table to: Lines_W4_boundaries.png
# Saved enhanced table to: Lines_W12_boundaries.png
# Saved enhanced table to: Lines_W22_boundaries.png
# Saved enhanced table to: Lines_W26_boundaries.png
# Saved enhanced table to: Lines_W32_boundaries.png
# Saved enhanced table to: Lines_W42_boundaries.png
# Saved enhanced table to: Lines_W52_boundaries.png

# %%
import os
import re
from pathlib import Path

def rename_lassa_files(folder_path):
    """
    Renames 'An_update_of_Lassa_fever_outbreak_in_Nigeria_041124_45.pdf'
    to 'Nigeria_04_Nov_24_W45.pdf', extracting day=04, month=11 => 'Nov', year=24,
    and the week number 45.
    
    Args:
        folder_path (str): Path to the folder that contains the PDF files.
    """
    # For mapping month number to short name
    month_map = {
        "01": "Jan", "02": "Feb", "03": "Mar", "04": "Apr",
        "05": "May", "06": "Jun", "07": "Jul", "08": "Aug",
        "09": "Sep", "10": "Oct", "11": "Nov", "12": "Dec",
    }

    folder = Path(folder_path)
    for file_path in folder.iterdir():
        if not file_path.is_file():
            continue
        if not file_path.suffix.lower() == ".pdf":
            continue
        
        old_name = file_path.name
        # Example old_name: "An_update_of_Lassa_fever_outbreak_in_Nigeria_041124_45.pdf"
        
        # 1) Split on underscores
        parts = old_name.split("_")
        # e.g. ["An","update","of","Lassa","fever","outbreak","in","Nigeria","041124","45.pdf"]
        
        if len(parts) < 9:
            # If the file name doesn't match the expected pattern, skip it
            print(f"Skipping file (unrecognized pattern): {old_name}")
            continue
        
        # 2) The date chunk is parts[8] like "041124"
        date_str = parts[8]  # "041124"
        
        # 3) The week chunk is in parts[9], but includes ".pdf" at the end, e.g. "45.pdf"
        week_str_pdf = parts[9]  # "45.pdf"
        # Remove ".pdf" from the end
        if week_str_pdf.endswith(".pdf"):
            week_str = week_str_pdf.replace(".pdf", "")
        else:
            print(f"Skipping file (no .pdf in last part): {old_name}")
            continue
        
        # 4) date_str should be 6 characters: DDMMYY
        if len(date_str) != 6:
            print(f"Skipping file (date string not 6 chars): {old_name}")
            continue
        dd = date_str[0:2]   # "04"
        mm = date_str[2:4]   # "11"
        yy = date_str[4:6]   # "24"
        
        # 5) Convert mm => month name
        month_name = month_map.get(mm, "???" )  # fallback "???"
        
        # 6) Build new name
        # e.g. "Nigeria_04_Nov_24_W45.pdf"
        new_name = f"Nigeria_{dd}_{month_name}_{yy}_W{week_str}.pdf"
        
        new_path = folder / new_name
        # 7) Rename the file
        print(f"Renaming:\n  {old_name}\n-> {new_name}\n")
        file_path.rename(new_path)

# Example usage:
if __name__ == "__main__":
    rename_lassa_files("PDFs")
